# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
print(int_words[:100])
print(int_to_vocab[63640])
# Out:
# [5233, 3080, 11, 5, 194, 1, 3133, 45, 58, 155, 127, 741, 476, 10571, 133, 0, 27349, 1, 0, 102, 854, 2, 0, 15067, 58112, 1, 0, 150, 854, 3580, 0, 194, 10, 190, 58, 4, 5, 10712, 214, 6, 1324, 104, 454, 19, 58, 2731, 362, 6, 3672, 0, 708, 1, 371, 26, 40, 36, 53, 539, 97, 11, 5, 1423, 2757, 18, 567, 686, 7088, 0, 247, 5233, 10, 1052, 27, 0, 320, 248, 44611, 2877, 792, 186, 5233, 11, 5, 200, 602, 10, 0, 1134, 19, 2621, 25, 8983, 2, 279, 31, 4147, 141, 59, 25, 6437]
# wigman

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

## Your code here
threshold = 1e-5
word_counts = Counter(int_words) # counts up all the words
total_count = len(int_words)

freqs = {word: count/total_count for word, count in word_counts.items()} #how often they show up in the whole dataset
p_drop = {word: 1 - np.sqrt(threshold / freqs[word]) for word in word_counts} # dictionary. word : probability
    

train_words = [word for word in int_words if random.random() < (1 - p_drop[word])] # prob to keep a word.

# %%
print(random.random())

# words - all the words from the articles
# Out:
# 0.18771528269364712

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size)
    start = idx - R if (idx - R) > 0 else 0
    end = idx + R
    
    target_words = set(words[start:idx] + words[idx+1:end+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like as usual.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer because we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From /home/ubuntu/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-81-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6275 0.0350 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6080 0.0271 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4746 0.0271 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5783 0.0269 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5255 0.0271 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5415 0.0270 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5477 0.0269 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5516 0.0269 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.5034 0.0269 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4341 0.0271 sec/batch
# Nearest to some: mettrie, loren, amman, lecoq, mohel, urgent, basayev, retired,
# Nearest to at: musicians, hairless, galilean, rooster, nominalist, erosive, ics, cholas,
# Nearest to he: namo, inference, massacre, europeans, abyssinia, betsy, arch, reversed,
# Nearest to while: follicle, chemical, roxy, sinc, apex, lay, geta, hanson,
# Nearest to states: transuranic, tridentine, yupik, rm, danny, vinca, albigensian, shifts,
# Nearest to first: havenworks, familiaris, epidemiology, maga, endpoint, franz, bounded, absconded,
# Nearest to or: telco, bohemian, detergent, ibf, annunzio, erupts, corrugated, rosalynn,
# Nearest to up: icty, requirements, casta, oppressors, nest, robot, grecian, ddrmax,
# Nearest to creation: cossack, gilgamesh, netbios, sobolev, heteroatom, semipalatinsk, manual, seminary,
# Nearest to pope: colorized, beccaria, tangerine, intercontinental, madhu, graded, histogram, craft,
# Nearest to bible: staunch, nance, hassidic, rte, hiding, haughty, redefine, backlight,
# Nearest to liberal: transfinite, cem, meteor, guido, iia, anzac, moralities, eventually,
# Nearest to professional: adored, railways, bohemia, overdue, metalwork, cfsp, wadsworth, stimuli,
# Nearest to accepted: maurya, murdering, unconcerned, pharmacology, happening, unfamiliarity, vance, joyce,
# Nearest to smith: standout, nouvelle, insuring, prohibitive, detoxification, yerushalayim, anemone, senna,
# Nearest to active: weak, blunted, homeported, weicker, lapd, microsoft, neum, brigadier,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5100 0.0282 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4103 0.0270 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3469 0.0269 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2484 0.0270 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1838 0.0269 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1665 0.0269 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1203 0.0269 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0879 0.0270 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9986 0.0269 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9961 0.0270 sec/batch
# Nearest to some: consisting, field, retired, mettrie, graphics, urgent, earning, lecoq,
# Nearest to at: musicians, hairless, galilean, nominalist, secondary, rooster, worthwhile, thriving,
# Nearest to he: inference, massacre, no, europeans, reversed, older, address, converting,
# Nearest to while: chemical, lay, stressed, rousseau, term, immigrants, sample, relationship,
# Nearest to states: in, tridentine, responsibility, a, understood, denmark, kit, yupik,
# Nearest to first: bounded, canada, havenworks, order, franz, epidemiology, lucrative, light,
# Nearest to or: telco, equations, criteria, bohemian, aims, nothing, manchuria, devolved,
# Nearest to up: requirements, remain, spread, casta, icty, oppressors, mighty, robot,
# Nearest to creation: cossack, manual, sobolev, netbios, gilgamesh, alone, seminary, prefer,
# Nearest to pope: graded, madhu, colorized, craft, finally, anointing, indianapolis, toulouse,
# Nearest to bible: staunch, nance, hiding, hassidic, quilt, fluid, energy, assumptions,
# Nearest to liberal: transfinite, cem, meteor, eventually, guido, comprehensive, criticisms, worldwide,
# Nearest to professional: railways, admission, prompted, adored, stimuli, metalwork, professor, orally,
# Nearest to accepted: characterize, happening, maurya, murdering, unconcerned, visions, joyce, books,
# Nearest to smith: standout, insuring, nouvelle, senna, yerushalayim, reversing, exclaves, shawn,
# Nearest to active: weak, blunted, microsoft, weicker, homeported, offered, lapd, neum,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9584 0.0279 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9172 0.0269 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9054 0.0270 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8608 0.0269 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7970 0.0268 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8154 0.0269 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8080 0.0269 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8028 0.0270 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7803 0.0271 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7611 0.0269 sec/batch
# Nearest to some: mettrie, urgent, consisting, loren, intentionally, graphics, decoding, philosophies,
# Nearest to at: musicians, galilean, worthwhile, hairless, heal, secondary, programme, thriving,
# Nearest to he: inference, namo, massacre, abyssinia, reversed, arch, betsy, no,
# Nearest to while: immigrants, rousseau, chemical, hanson, sample, lay, roxy, stressed,
# Nearest to states: in, responsibility, tridentine, denmark, rm, danny, peninsula, shifts,
# Nearest to first: bounded, havenworks, franz, choke, scheme, canada, pohl, lucrative,
# Nearest to or: criteria, equations, telco, devolved, assessed, moderate, bohemian, dostoyevsky,
# Nearest to up: requirements, robot, oppressors, casta, icty, remain, spread, nest,
# Nearest to creation: cossack, gilgamesh, sobolev, manual, netbios, seminary, heteroatom, exceeded,
# Nearest to pope: graded, craft, madhu, colorized, substantiated, sexton, finally, toulouse,
# Nearest to bible: staunch, hiding, nance, assumptions, hassidic, popular, manipulated, quilt,
# Nearest to liberal: transfinite, guido, meteor, cem, criticisms, eventually, comprehensive, anzac,
# Nearest to professional: railways, admission, stimuli, marxists, adored, bohemia, prompted, metalwork,
# Nearest to accepted: happening, pharmacology, characterize, maurya, murdering, unconcerned, visions, persisting,
# Nearest to smith: standout, insuring, definition, reversing, nouvelle, senna, exclaves, yerushalayim,
# Nearest to active: weak, microsoft, blunted, weicker, homeported, lapd, brigadier, tracking,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7741 0.0279 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7450 0.0269 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7332 0.0268 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7214 0.0268 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7174 0.0270 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7369 0.0270 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7248 0.0269 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7477 0.0270 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7047 0.0271 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6419 0.0270 sec/batch
# Nearest to some: intentionally, urgent, mettrie, consisting, amman, decoding, loren, lombards,
# Nearest to at: worthwhile, musicians, galilean, hairless, mueller, simms, heal, rwandan,
# Nearest to he: abyssinia, massacre, arch, namo, inference, betsy, europeans, reversed,
# Nearest to while: hanson, rousseau, roxy, chemical, immigrants, sinc, rag, apex,
# Nearest to states: in, responsibility, peninsula, denmark, tridentine, yupik, rm, vinca,
# Nearest to first: havenworks, choke, batavia, bounded, pohl, epidemiology, canada, lucrative,
# Nearest to or: devolved, criteria, equations, telco, assessed, hypnosis, allocated, dostoyevsky,
# Nearest to up: requirements, nest, icty, robot, oppressors, akron, spread, mighty,
# Nearest to creation: cossack, gilgamesh, sobolev, seminary, heteroatom, netbios, manual, vegetarian,
# Nearest to pope: madhu, graded, colorized, sexton, intercontinental, craft, tangerine, substantiated,
# Nearest to bible: staunch, hassidic, hiding, kjv, nance, manipulated, textual, quentin,
# Nearest to liberal: meteor, cem, transfinite, guido, eventually, anzac, criticisms, cretaceous,
# Nearest to professional: adored, railways, bohemia, stimuli, overdue, wadsworth, prompted, metalwork,
# Nearest to accepted: pharmacology, unconcerned, maurya, happening, characterize, murdering, joyce, deficits,
# Nearest to smith: standout, insuring, reversing, yerushalayim, definition, exclaves, buenos, senna,
# Nearest to active: weak, blunted, microsoft, weicker, lapd, brigadier, homeported, tracking,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6680 0.0278 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6801 0.0269 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6094 0.0270 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6041 0.0269 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.5962 0.0269 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6568 0.0268 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6236 0.0199 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5842 0.0269 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5327 0.0269 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5064 0.0269 sec/batch
# Nearest to some: intentionally, mettrie, urgent, amman, decoding, philosophies, beliefs, gre,
# Nearest to at: worthwhile, hairless, galilean, musicians, simms, augmentation, sherpa, manicheanism,
# Nearest to he: abyssinia, massacre, betsy, wife, arch, after, europeans, namo,
# Nearest to while: roxy, hanson, rousseau, sinc, apex, rulebase, immigrants, detected,
# Nearest to states: in, peninsula, responsibility, feudatories, vinca, denmark, yupik, border,
# Nearest to first: havenworks, batavia, intimidate, pohl, choke, kristen, overworked, lucrative,
# Nearest to or: criteria, devolved, equations, telco, assessed, hypnosis, allocated, derives,
# Nearest to up: requirements, oppressors, icty, nest, robot, spread, akron, mighty,
# Nearest to creation: gilgamesh, sobolev, cossack, heteroatom, seminary, netbios, manual, vegetarian,
# Nearest to pope: madhu, sexton, toulouse, graded, colorized, stengel, intercontinental, oligopoly,
# Nearest to bible: staunch, hassidic, kjv, hiding, hurrian, nance, manipulated, redefine,
# Nearest to liberal: meteor, cem, alkane, anzac, moralities, cretaceous, transfinite, guido,
# Nearest to professional: adored, stimuli, wadsworth, bohemia, menstruation, inadmissible, gaol, habash,
# Nearest to accepted: unconcerned, pharmacology, murdering, maurya, characterize, visions, unfamiliarity, joyce,
# Nearest to smith: standout, insuring, exclaves, yerushalayim, nouvelle, buenos, shawn, reversing,
# Nearest to active: weak, blunted, weicker, microsoft, lapd, brigadier, neum, homeported,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4780 0.0280 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5013 0.0269 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4746 0.0269 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.4980 0.0269 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4862 0.0268 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4802 0.0268 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4752 0.0269 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3911 0.0269 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4469 0.0268 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4253 0.0268 sec/batch
# Nearest to some: amman, intentionally, mettrie, philosophies, urgent, lombards, beliefs, decoding,
# Nearest to at: worthwhile, hairless, galilean, augmentation, simms, cholas, musicians, manicheanism,
# Nearest to he: abyssinia, him, massacre, wife, after, betsy, no, arch,
# Nearest to while: roxy, hanson, rousseau, sinc, respondents, rulebase, stewie, apex,
# Nearest to states: peninsula, in, responsibility, border, republic, feudatories, prosperous, vinca,
# Nearest to first: havenworks, intimidate, choke, pohl, batavia, kristen, overworked, epidemiology,
# Nearest to or: criteria, devolved, telco, equations, detergent, assessed, derives, thus,
# Nearest to up: oppressors, requirements, akron, icty, spread, waals, robot, mighty,
# Nearest to creation: gilgamesh, sobolev, heteroatom, cossack, stewardship, netbios, seminary, vegetarian,
# Nearest to pope: sexton, madhu, toulouse, stengel, oligopoly, colorized, graded, excursion,
# Nearest to bible: kjv, staunch, hassidic, hurrian, biblical, covenants, textual, tanakh,
# Nearest to liberal: alkane, anzac, cem, criticisms, moralities, amadeus, cretaceous, modulate,
# Nearest to professional: wadsworth, inadmissible, adored, gaol, habash, overdue, menstruation, speeded,
# Nearest to accepted: unconcerned, pharmacology, murdering, visions, characterize, maurya, unfamiliarity, joyce,
# Nearest to smith: standout, insuring, exclaves, nouvelle, buenos, shawn, yerushalayim, oblates,
# Nearest to active: weak, blunted, neum, microsoft, weicker, lapd, brigadier, tracking,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4313 0.0277 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3874 0.0269 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4278 0.0269 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3822 0.0269 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4229 0.0269 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4203 0.0269 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3802 0.0272 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3701 0.0273 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4322 0.0271 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3708 0.0269 sec/batch
# Nearest to some: amman, mettrie, lombards, urgent, philosophies, intentionally, decoding, prejudice,
# Nearest to at: worthwhile, galilean, nominalist, simms, cholas, manicheanism, musicians, password,
# Nearest to he: him, after, abyssinia, massacre, wife, no, his, betsy,
# Nearest to while: roxy, sinc, rulebase, rousseau, hanson, respondents, stewie, luthiers,
# Nearest to states: peninsula, in, responsibility, parties, feudatories, border, vinca, denmark,
# Nearest to first: havenworks, intimidate, kristen, choke, pohl, yr, cameraman, vaud,
# Nearest to or: criteria, devolved, telco, allocated, equations, corrugated, detergent, derives,
# Nearest to up: oppressors, requirements, akron, spread, mighty, icty, waals, cve,
# Nearest to creation: gilgamesh, sobolev, heteroatom, cossack, seminary, vegetarian, mazar, stewardship,
# Nearest to pope: sexton, toulouse, madhu, stengel, oligopoly, excursion, ecclesiastical, popes,
# Nearest to bible: kjv, staunch, hassidic, hurrian, covenants, textual, evangelical, christians,
# Nearest to liberal: alkane, anzac, criticisms, cem, moralities, modulate, cretaceous, amadeus,
# Nearest to professional: inadmissible, wadsworth, adored, habash, gaol, nasdaq, speeded, jd,
# Nearest to accepted: unconcerned, pharmacology, visions, characterize, maurya, murdering, unfamiliarity, joyce,
# Nearest to smith: standout, insuring, shawn, exclaves, buenos, nouvelle, yerushalayim, germs,
# Nearest to active: blunted, weak, microsoft, neum, weicker, lapd, tracking, requirement,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3732 0.0278 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3845 0.0270 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3427 0.0269 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3502 0.0269 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3969 0.0270 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3723 0.0271 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3884 0.0269 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3602 0.0269 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3253 0.0269 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3351 0.0268 sec/batch
# Nearest to some: amman, lombards, mettrie, urgent, prejudice, philosophies, fittings, segregationist,
# Nearest to at: worthwhile, manicheanism, rwandan, nominalist, galilean, simms, cholas, mueller,
# Nearest to he: him, abyssinia, namo, after, betsy, wife, massacre, his,
# Nearest to while: roxy, sinc, rulebase, hanson, respondents, kari, stewie, rousseau,
# Nearest to states: in, responsibility, parties, peninsula, feudatories, insurrections, yupik, nagpur,
# Nearest to first: havenworks, intimidate, yr, carrera, pohl, domingue, kristen, cameraman,
# Nearest to or: criteria, devolved, detergent, telco, derives, allocated, hypnosis, tasting,
# Nearest to up: oppressors, requirements, akron, robot, nest, spread, receivers, assembling,
# Nearest to creation: gilgamesh, heteroatom, sobolev, seminary, mazar, cossack, stewardship, vegetarian,
# Nearest to pope: sexton, toulouse, madhu, ecclesiastical, popes, stengel, oligopoly, excursion,
# Nearest to bible: kjv, textual, staunch, tanakh, hurrian, christians, covenants, hassidic,
# Nearest to liberal: alkane, anzac, criticisms, cem, moralities, amadeus, socialist, cretaceous,
# Nearest to professional: inadmissible, wadsworth, gaol, habash, nasdaq, jd, professor, adored,
# Nearest to accepted: unconcerned, pharmacology, visions, characterize, maurya, unfamiliarity, persisting, lizzy,
# Nearest to smith: standout, insuring, shawn, buenos, exclaves, yerushalayim, scout, nouvelle,
# Nearest to active: weak, neum, blunted, microsoft, weicker, lapd, tracking, belgae,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3488 0.0280 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2737 0.0270 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3726 0.0270 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3578 0.0271 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3976 0.0268 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2942 0.0269 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3135 0.0268 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3423 0.0269 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2352 0.0272 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2853 0.0270 sec/batch
# Nearest to some: amman, lombards, urgent, mettrie, prejudice, deadliest, philosophies, gottorp,
# Nearest to at: manicheanism, worthwhile, galilean, nominalist, simms, beatty, sherpa, rwandan,
# Nearest to he: him, namo, after, betsy, no, abyssinia, reconciling, his,
# Nearest to while: roxy, sinc, rulebase, hanson, respondents, kari, rousseau, immigrants,
# Nearest to states: in, parties, responsibility, feudatories, insurrections, peninsula, vinca, nagpur,
# Nearest to first: havenworks, intimidate, yr, telekinetic, domingue, cameraman, batavia, carrera,
# Nearest to or: criteria, devolved, derives, detergent, descriptive, allocated, corrugated, hypnosis,
# Nearest to up: oppressors, requirements, akron, mighty, robot, tripping, nest, nlp,
# Nearest to creation: gilgamesh, heteroatom, cossack, sobolev, mazar, vegetarian, stewardship, seminary,
# Nearest to pope: sexton, popes, ecclesiastical, toulouse, papal, madhu, stengel, papacy,
# Nearest to bible: kjv, textual, tanakh, hurrian, covenants, biblical, staunch, hassidic,
# Nearest to liberal: alkane, criticisms, anzac, socialist, moralities, cem, amadeus, meighen,
# Nearest to professional: inadmissible, basketball, gaol, habash, jd, professor, adored, wadsworth,
# Nearest to accepted: unconcerned, characterize, pharmacology, visions, maurya, guaranteeing, unfamiliarity, acquainted,
# Nearest to smith: standout, insuring, shawn, buenos, nouvelle, macrae, oblates, scout,
# Nearest to active: neum, blunted, weak, microsoft, weicker, lapd, belgae, organizations,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2840 0.0279 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2845 0.0270 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3240 0.0126 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2566 0.0270 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2271 0.0269 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2265 0.0270 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1933 0.0268 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2186 0.0269 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2217 0.0270 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1532 0.0269 sec/batch
# Nearest to some: amman, lombards, prejudice, urgent, arabs, gre, compressors, deadliest,
# Nearest to at: manicheanism, worthwhile, rwandan, nominalist, apprehended, threads, cholas, westerly,
# Nearest to he: him, his, after, abyssinia, betsy, namo, massacre, reconciling,
# Nearest to while: sinc, roxy, hanson, rulebase, rousseau, respondents, kari, immigrants,
# Nearest to states: in, responsibility, parties, nagpur, vinca, feudatories, mauritius, yupik,
# Nearest to first: havenworks, domingue, intimidate, telekinetic, carrera, yr, cameraman, rustin,
# Nearest to or: criteria, devolved, detergent, telco, allocated, descriptive, ports, hypnosis,
# Nearest to up: oppressors, requirements, akron, mighty, spread, cve, nlp, improv,
# Nearest to creation: gilgamesh, heteroatom, sobolev, stewardship, cossack, vegetarian, mazar, currie,
# Nearest to pope: toulouse, popes, sexton, papal, ecclesiastical, papacy, stengel, madhu,
# Nearest to bible: kjv, textual, tanakh, biblical, covenants, hurrian, hassidic, staunch,
# Nearest to liberal: alkane, criticisms, anzac, moralities, amadeus, meighen, cem, socialist,
# Nearest to professional: inadmissible, habash, basketball, jd, gaol, nasdaq, wadsworth, professor,
# Nearest to accepted: unconcerned, characterize, maurya, visions, pharmacology, unfamiliarity, acquainted, murdering,
# Nearest to smith: standout, insuring, shawn, nouvelle, oblates, verte, macrae, scepter,
# Nearest to active: neum, weak, blunted, microsoft, weicker, lapd, belgae, producing,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2173 0.0278 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2484 0.0269 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2149 0.0269 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1376 0.0269 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1733 0.0268 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1675 0.0269 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1579 0.0268 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1566 0.0269 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1790 0.0268 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1544 0.0268 sec/batch
# Nearest to some: amman, deadliest, urgent, compressors, lombards, gre, prejudice, gottorp,
# Nearest to at: manicheanism, threads, worthwhile, minefields, nominalist, apprehended, galilean, erupting,
# Nearest to he: him, betsy, his, namo, after, abyssinia, she, inference,
# Nearest to while: sinc, roxy, rulebase, rousseau, respondents, narrower, erasable, hanson,
# Nearest to states: in, nagpur, parties, responsibility, vinca, yupik, feudatories, insurrections,
# Nearest to first: havenworks, intimidate, yr, telekinetic, cameraman, domingue, rustin, ankles,
# Nearest to or: devolved, criteria, derives, detergent, hypnosis, telco, allocated, corrugated,
# Nearest to up: oppressors, requirements, mighty, them, cve, akron, blinds, spread,
# Nearest to creation: gilgamesh, heteroatom, sobolev, adversus, stewardship, seminary, vegetarian, netbios,
# Nearest to pope: popes, toulouse, papal, sancti, papacy, sexton, ecclesiastical, madhu,
# Nearest to bible: kjv, textual, tanakh, biblical, translations, rashi, covenants, prophets,
# Nearest to liberal: criticisms, alkane, anzac, meighen, moralities, socialist, slidell, transfinite,
# Nearest to professional: inadmissible, habash, basketball, gaol, nasdaq, jd, lettering, wadsworth,
# Nearest to accepted: unconcerned, characterize, maurya, visions, pharmacology, unfamiliarity, hellenized, persisting,
# Nearest to smith: standout, shawn, insuring, nouvelle, verte, oblates, chronicling, scepter,
# Nearest to active: neum, weak, microsoft, blunted, secrete, producing, cameroon, disparage,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1388 0.0279 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2115 0.0270 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1414 0.0269 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1249 0.0269 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2018 0.0269 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1649 0.0268 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1711 0.0269 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1461 0.0269 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1241 0.0268 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1664 0.0269 sec/batch
# Nearest to some: amman, lombards, urgent, compressors, gre, deadliest, gottorp, prejudice,
# Nearest to at: manicheanism, worthwhile, apprehended, thereafter, galilean, threads, nominalist, rwandan,
# Nearest to he: betsy, namo, his, him, inference, after, reconciling, she,
# Nearest to while: sinc, fijians, roxy, rulebase, respondents, erasable, rousseau, narrower,
# Nearest to states: in, nagpur, parties, yupik, insurrections, vinca, feudatories, responsibility,
# Nearest to first: havenworks, cameraman, telekinetic, intimidate, yr, scheme, domingue, carrera,
# Nearest to or: devolved, criteria, detergent, corrugated, telco, recombinant, ultrasonic, rather,
# Nearest to up: oppressors, mighty, requirements, blinds, cve, them, icty, akron,
# Nearest to creation: gilgamesh, heteroatom, stewardship, adversus, sobolev, vegetarian, seminary, netbios,
# Nearest to pope: popes, papal, toulouse, papacy, sancti, madhu, sexton, clement,
# Nearest to bible: kjv, textual, tanakh, hurrian, rashi, hassidic, translations, biblical,
# Nearest to liberal: criticisms, alkane, moralities, socialist, meighen, anzac, guido, slidell,
# Nearest to professional: inadmissible, basketball, habash, nasdaq, gaol, wrestler, lettering, professor,
# Nearest to accepted: unconcerned, characterize, pharmacology, maurya, unfamiliarity, visions, persisting, judgments,
# Nearest to smith: standout, shawn, insuring, nouvelle, verte, conformist, reversing, buenos,
# Nearest to active: neum, weak, microsoft, blunted, secrete, cameroon, producing, disparage,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1872 0.0278 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1333 0.0270 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1580 0.0268 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1844 0.0269 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1584 0.0269 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1155 0.0269 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1532 0.0269 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1085 0.0270 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2055 0.0270 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1716 0.0270 sec/batch
# Nearest to some: amman, lombards, gottorp, prejudice, urgent, allegory, arabs, deadliest,
# Nearest to at: manicheanism, thereafter, beatty, worthwhile, apprehended, nominalist, rwandan, bendis,
# Nearest to he: his, him, namo, betsy, after, theodora, reconciling, xd,
# Nearest to while: stewie, roxy, sinc, fijians, rousseau, rulebase, respondents, immigrants,
# Nearest to states: in, yupik, insurrections, nagpur, feudatories, vinca, mauritius, responsibility,
# Nearest to first: havenworks, domingue, cameraman, telekinetic, yr, mota, carrera, intimidate,
# Nearest to or: devolved, criteria, muslim, comstock, beretitenti, clause, descriptive, corrugated,
# Nearest to up: oppressors, mighty, them, icty, requirements, blinds, arafura, cve,
# Nearest to creation: gilgamesh, heteroatom, adversus, stewardship, currie, sobolev, netbios, seminary,
# Nearest to pope: popes, papal, toulouse, papacy, madhu, sancti, graded, stengel,
# Nearest to bible: kjv, textual, hassidic, rashi, yahweh, judeo, hurrian, tanakh,
# Nearest to liberal: criticisms, meighen, moralities, alkane, slidell, socialist, moderate, guido,
# Nearest to professional: inadmissible, wrestler, basketball, quarterbacks, habash, nasdaq, gaol, lettering,
# Nearest to accepted: unconcerned, maurya, characterize, judgments, hellenized, unfamiliarity, acquainted, guaranteeing,
# Nearest to smith: standout, insuring, shawn, chronicling, verte, mathews, reversing, conformist,
# Nearest to active: neum, weak, blunted, microsoft, disparage, cameroon, secrete, producing,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2425 0.0277 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1324 0.0270 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1348 0.0268 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1232 0.0269 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0494 0.0269 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1323 0.0271 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1308 0.0268 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1096 0.0268 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1480 0.0054 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0779 0.0269 sec/batch
# Nearest to some: amman, lombards, allegory, deadliest, prejudice, compressors, refers, urgent,
# Nearest to at: manicheanism, thereafter, apprehended, threads, worthwhile, erupting, nominalist, bendis,
# Nearest to he: his, him, namo, betsy, after, theodora, inference, assuage,
# Nearest to while: fijians, roxy, stewie, respondents, rulebase, immigrants, makin, narrower,
# Nearest to states: in, nagpur, yupik, insurrections, mauritius, feudatories, embargo, vinca,
# Nearest to first: havenworks, telekinetic, intimidate, domingue, cameraman, rustin, the, yr,
# Nearest to or: criteria, devolved, clause, hypnosis, comstock, rather, descriptive, corrugated,
# Nearest to up: oppressors, arafura, blinds, mighty, requirements, them, cve, icty,
# Nearest to creation: gilgamesh, heteroatom, netbios, adversus, sobolev, stewardship, currie, nathanael,
# Nearest to pope: popes, papal, toulouse, madhu, papacy, sancti, graded, sexton,
# Nearest to bible: kjv, textual, hassidic, hurrian, yahweh, rashi, tanakh, judeo,
# Nearest to liberal: criticisms, meighen, moralities, alkane, guido, slidell, socialist, marxism,
# Nearest to professional: wrestler, inadmissible, basketball, habash, quarterbacks, nasdaq, assuring, adored,
# Nearest to accepted: unconcerned, characterize, maurya, judgments, acquainted, hellenized, pharmacology, guaranteeing,
# Nearest to smith: standout, insuring, shawn, reversing, verte, chronicling, conformist, mathews,
# Nearest to active: neum, weak, blunted, microsoft, cameroon, disparage, requirement, secrete,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0908 0.0278 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0599 0.0270 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0790 0.0270 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0471 0.0269 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0858 0.0269 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0212 0.0269 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0735 0.0270 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0773 0.0269 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1105 0.0269 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0096 0.0269 sec/batch
# Nearest to some: amman, compressors, urgent, deadliest, prejudice, minimal, lombards, refers,
# Nearest to at: manicheanism, thereafter, westerly, erupting, apprehended, worthwhile, threads, augmentation,
# Nearest to he: his, him, after, betsy, namo, theodora, himself, inference,
# Nearest to while: fijians, respondents, sinc, rousseau, narrower, rulebase, immigrants, roxy,
# Nearest to states: in, nagpur, yupik, mauritius, insurrections, feudatories, embargo, vinca,
# Nearest to first: havenworks, intimidate, rustin, telekinetic, the, cameraman, domingue, mota,
# Nearest to or: devolved, criteria, resembling, clause, detergent, corrugated, beretitenti, lewd,
# Nearest to up: oppressors, them, arafura, cve, blinds, requirements, remain, icty,
# Nearest to creation: gilgamesh, netbios, heteroatom, sobolev, adversus, stewardship, nathanael, arithmeticae,
# Nearest to pope: popes, papal, toulouse, papacy, sancti, madhu, graded, benedict,
# Nearest to bible: kjv, textual, rashi, judeo, yahweh, tanakh, hassidic, covenants,
# Nearest to liberal: meighen, criticisms, slidell, alkane, moralities, democratic, guido, marxism,
# Nearest to professional: wrestler, inadmissible, basketball, habash, quarterbacks, lettering, nasdaq, gaol,
# Nearest to accepted: unconcerned, characterize, maurya, acquainted, hellenized, godf, visions, judgments,
# Nearest to smith: standout, insuring, conformist, chronicling, shawn, reversing, verte, mathews,
# Nearest to active: neum, weak, secrete, microsoft, blunted, translational, producing, cameroon,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0167 0.0278 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0193 0.0268 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0061 0.0268 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0485 0.0268 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0666 0.0269 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0243 0.0270 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0655 0.0269 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0750 0.0269 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0415 0.0270 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0163 0.0270 sec/batch
# Nearest to some: amman, minimal, urgent, compressors, refers, are, deadliest, recognized,
# Nearest to at: manicheanism, thereafter, nominalist, nist, worthwhile, erupting, threads, journ,
# Nearest to he: his, him, betsy, after, namo, inference, theodora, worked,
# Nearest to while: fijians, respondents, sinc, narrower, rulebase, rousseau, stewie, erasable,
# Nearest to states: in, nagpur, yupik, insurrections, schengen, violated, feudatories, vinca,
# Nearest to first: cameraman, havenworks, intimidate, rustin, telekinetic, the, mota, yr,
# Nearest to or: devolved, criteria, resembling, clause, corrugated, only, be, detergent,
# Nearest to up: oppressors, blinds, them, arafura, cve, requirements, ddrmax, icty,
# Nearest to creation: gilgamesh, heteroatom, adversus, sobolev, netbios, nathanael, arithmeticae, tandy,
# Nearest to pope: popes, papal, toulouse, papacy, sancti, graded, madhu, thirtieth,
# Nearest to bible: kjv, textual, rashi, tanakh, yahweh, hassidic, covenants, hurrian,
# Nearest to liberal: criticisms, meighen, alkane, slidell, moralities, marxism, transfinite, moderate,
# Nearest to professional: inadmissible, wrestler, basketball, training, habash, lettering, nasdaq, promotion,
# Nearest to accepted: unconcerned, characterize, maurya, judgments, acquainted, godf, carlson, visions,
# Nearest to smith: standout, insuring, reversing, conformist, shawn, chronicling, verte, mathews,
# Nearest to active: neum, weak, secrete, blunted, disparage, microsoft, translational, producing,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0378 0.0278 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0585 0.0269 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0598 0.0268 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0230 0.0269 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0497 0.0270 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0273 0.0269 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0463 0.0269 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0255 0.0269 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0544 0.0270 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0570 0.0268 sec/batch
# Nearest to some: lombards, gottorp, foreigner, minimal, urgent, deadliest, categorize, amman,
# Nearest to at: manicheanism, thereafter, six, threads, westerly, years, nominalist, journ,
# Nearest to he: his, him, after, betsy, namo, theodora, inference, worked,
# Nearest to while: fijians, respondents, sinc, stewie, rousseau, narrower, roxy, lani,
# Nearest to states: in, nagpur, yupik, insurrections, schengen, feudatories, embargo, mauritius,
# Nearest to first: cameraman, rustin, telekinetic, havenworks, of, the, trent, intimidate,
# Nearest to or: clause, devolved, corrugated, resembling, rather, criteria, recombinant, beretitenti,
# Nearest to up: oppressors, arafura, them, icty, blinds, excesses, ddrmax, cve,
# Nearest to creation: gilgamesh, heteroatom, adversus, nathanael, netbios, arithmeticae, sobolev, currie,
# Nearest to pope: popes, papal, papacy, toulouse, sancti, graded, thirtieth, disavow,
# Nearest to bible: kjv, textual, hurrian, tanakh, rashi, hassidic, old, yahweh,
# Nearest to liberal: meighen, criticisms, moralities, slidell, fdp, alkane, moderate, democratic,
# Nearest to professional: wrestler, inadmissible, basketball, habash, lettering, assuring, promotion, newsgroups,
# Nearest to accepted: unconcerned, maurya, characterize, acquainted, godf, judgments, visions, conservatively,
# Nearest to smith: standout, reversing, insuring, shawn, conformist, thorne, mathews, germs,
# Nearest to active: neum, weak, secrete, disparage, blunted, microsoft, cameroon, translational,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0476 0.0278 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0029 0.0269 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0199 0.0268 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0540 0.0271 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0816 0.0270 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1108 0.0269 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1150 0.0268 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0470 0.0270 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0215 0.0269 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0535 0.0268 sec/batch
# Nearest to some: amman, gottorp, refers, minimal, recognized, foreigner, allegory, categorize,
# Nearest to at: manicheanism, thereafter, six, threads, worthwhile, journ, years, nominalist,
# Nearest to he: his, him, after, namo, betsy, worked, inference, theodora,
# Nearest to while: respondents, fijians, stewie, sinc, rousseau, lani, makin, narrower,
# Nearest to states: in, yupik, nagpur, schengen, violated, insurrections, mauritius, united,
# Nearest to first: cameraman, the, of, domingue, havenworks, rustin, mota, telekinetic,
# Nearest to or: devolved, corrugated, criteria, lewd, clause, beretitenti, resembling, detergent,
# Nearest to up: oppressors, icty, arafura, them, blinds, ddrmax, excesses, lakeview,
# Nearest to creation: gilgamesh, heteroatom, adversus, nathanael, currie, netbios, arithmeticae, sobolev,
# Nearest to pope: popes, papal, papacy, toulouse, sancti, graded, thirtieth, ecclesiastical,
# Nearest to bible: kjv, textual, rashi, hurrian, tanakh, judeo, hassidic, yahweh,
# Nearest to liberal: meighen, criticisms, moralities, slidell, alkane, transfinite, democratic, fdp,
# Nearest to professional: wrestler, basketball, inadmissible, quarterbacks, habash, lettering, tap, nasdaq,
# Nearest to accepted: unconcerned, maurya, godf, judgments, characterize, acquainted, raison, visions,
# Nearest to smith: standout, insuring, reversing, conformist, thorne, mathews, germs, scepter,
# Nearest to active: neum, weak, disparage, blunted, microsoft, requirement, bcl, cameroon,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9608 0.0279 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9937 0.0269 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0029 0.0269 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0008 0.0269 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0577 0.0269 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0330 0.0250 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0134 0.0269 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9670 0.0269 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9850 0.0269 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9832 0.0269 sec/batch
# Nearest to some: amman, refers, minimal, are, allegory, lombards, gottorp, foreigner,
# Nearest to at: thereafter, manicheanism, six, nominalist, ezln, erupting, years, threads,
# Nearest to he: his, him, after, theodora, namo, betsy, himself, worked,
# Nearest to while: fijians, stewie, respondents, lani, rousseau, narrower, hetzel, makin,
# Nearest to states: in, nagpur, yupik, united, schengen, insurrections, danny, mauritius,
# Nearest to first: the, cameraman, rustin, of, batavia, intimidate, havenworks, domingue,
# Nearest to or: devolved, cheek, clause, beretitenti, criteria, paraphyletic, resembling, lewd,
# Nearest to up: oppressors, them, arafura, icty, cve, blinds, ddrmax, excesses,
# Nearest to creation: gilgamesh, heteroatom, netbios, adversus, nathanael, currie, sobolev, tandy,
# Nearest to pope: papal, popes, papacy, toulouse, sancti, thirtieth, graded, ecclesiastical,
# Nearest to bible: kjv, textual, hurrian, tanakh, rashi, yahweh, covenants, old,
# Nearest to liberal: meighen, criticisms, moralities, alkane, slidell, transfinite, fdp, guido,
# Nearest to professional: wrestler, basketball, inadmissible, quarterbacks, training, promotion, nasdaq, habash,
# Nearest to accepted: unconcerned, godf, maurya, judgments, acquainted, characterize, visions, raison,
# Nearest to smith: standout, insuring, conformist, reversing, mathews, shawn, thorne, verte,
# Nearest to active: neum, weak, disparage, bcl, translational, atropine, blunted, cameroon,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9940 0.0279 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9212 0.0268 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0223 0.0268 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0213 0.0268 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0122 0.0267 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9926 0.0270 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8829 0.0268 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9551 0.0269 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9345 0.0268 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9680 0.0270 sec/batch
# Nearest to some: are, amman, minimal, of, discontinuation, promulgate, gottorp, refers,
# Nearest to at: manicheanism, thereafter, years, six, monorail, threads, erupting, worthwhile,
# Nearest to he: his, him, betsy, namo, after, inference, worked, himself,
# Nearest to while: respondents, fijians, narrower, lani, stewie, unlock, snap, rousseau,
# Nearest to states: in, nagpur, united, schengen, yupik, violated, mauritius, vinca,
# Nearest to first: the, rustin, cameraman, of, intimidate, batavia, havenworks, score,
# Nearest to or: resembling, devolved, cheek, criteria, detergent, corrugated, beretitenti, paraphyletic,
# Nearest to up: oppressors, them, arafura, icty, cve, average, germline, lakeview,
# Nearest to creation: gilgamesh, heteroatom, netbios, adversus, nathanael, sobolev, rabbinical, tandy,
# Nearest to pope: papal, popes, papacy, toulouse, sancti, thirtieth, graded, disavow,
# Nearest to bible: kjv, textual, tanakh, rashi, old, adonai, yahweh, covenants,
# Nearest to liberal: meighen, criticisms, alkane, slidell, moralities, fdp, moderate, democratic,
# Nearest to professional: wrestler, basketball, inadmissible, training, promotion, trained, habash, lettering,
# Nearest to accepted: unconcerned, godf, judgments, maurya, characterize, visions, acquainted, carlson,
# Nearest to smith: standout, insuring, conformist, reversing, verte, chronicling, thorne, mathews,
# Nearest to active: neum, weak, disparage, secrete, bcl, atropine, cameroon, microsoft,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9846 0.0279 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0100 0.0269 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9557 0.0268 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9841 0.0268 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0280 0.0269 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9366 0.0269 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9662 0.0269 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9740 0.0269 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9556 0.0269 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9572 0.0268 sec/batch
# Nearest to some: are, minimal, amman, categorize, gottorp, promulgate, townships, recognized,
# Nearest to at: manicheanism, thereafter, worthwhile, nominalist, nist, years, journ, six,
# Nearest to he: his, him, betsy, worked, namo, inference, career, after,
# Nearest to while: fijians, respondents, lani, unlock, snap, stewie, sinc, hetzel,
# Nearest to states: in, united, schengen, nagpur, violated, yupik, insurrections, embargo,
# Nearest to first: the, cameraman, of, rustin, telekinetic, intimidate, mota, ankles,
# Nearest to or: criteria, clause, cheek, corrugated, devolved, resembling, only, be,
# Nearest to up: them, oppressors, arafura, blinds, lakeview, cve, icty, average,
# Nearest to creation: gilgamesh, heteroatom, arithmeticae, netbios, adversus, sobolev, nathanael, currie,
# Nearest to pope: papal, popes, papacy, thirtieth, toulouse, sancti, abdicating, graded,
# Nearest to bible: kjv, textual, rashi, adonai, yahweh, tanakh, covenants, old,
# Nearest to liberal: criticisms, meighen, alkane, moralities, slidell, fdp, transfinite, guido,
# Nearest to professional: wrestler, basketball, inadmissible, training, trained, quarterbacks, lettering, habash,
# Nearest to accepted: unconcerned, judgments, characterize, godf, visions, carlson, acquainted, maurya,
# Nearest to smith: standout, insuring, conformist, reversing, verte, germs, thorne, chronicling,
# Nearest to active: weak, neum, disparage, secrete, microsoft, bcl, translational, cameroon,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9827 0.0279 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9811 0.0269 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9660 0.0269 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9718 0.0268 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9843 0.0269 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9807 0.0269 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9724 0.0268 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9513 0.0269 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9524 0.0268 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9984 0.0270 sec/batch
# Nearest to some: are, amman, minimal, recognized, have, gottorp, varies, townships,
# Nearest to at: thereafter, worthwhile, manicheanism, years, nominalist, journ, nist, guardianship,
# Nearest to he: his, him, betsy, worked, career, namo, after, himself,
# Nearest to while: respondents, fijians, lani, stewie, rousseau, undercroft, unlock, snap,
# Nearest to states: in, united, schengen, nagpur, yupik, violated, insurrections, resident,
# Nearest to first: the, of, cameraman, rustin, telekinetic, batavia, mota, maga,
# Nearest to or: clause, criteria, corrugated, subject, cheek, devolved, example, recombinant,
# Nearest to up: them, oppressors, icty, lakeview, arafura, excesses, average, cve,
# Nearest to creation: gilgamesh, heteroatom, adversus, arithmeticae, nathanael, netbios, tandy, mazar,
# ...
# Nearest to some: are, have, that, most, many, however, of, such,
# Nearest to at: the, a, years, until, on, thereafter, s, worthwhile,
# Nearest to he: his, worked, career, himself, him, after, retirement, soon,
# Nearest to while: unlock, undercroft, has, hancock, sinc, semitones, fijians, blvd,
# Nearest to states: united, schengen, in, embargo, firearm, new, sylvester, kemper,
# Nearest to first: the, of, a, after, in, an, which, was,
# Nearest to or: the, is, although, for, of, used, only, subject,
# Nearest to up: them, arafura, lagging, blinds, average, spread, took, household,
# Nearest to creation: gilgamesh, creator, creationist, partnership, heteroatom, arithmeticae, numerological, elish,
# Nearest to pope: papal, papacy, popes, thirtieth, avignon, sancti, abdicating, graded,
# Nearest to bible: kjv, bibles, rashi, hurrian, translations, textual, biblical, scholars,
# Nearest to liberal: meighen, conservatives, transfinite, fdp, moralities, conservative, criticisms, bloc,
# Nearest to professional: wrestler, basketball, training, itil, inadmissible, degree, courses, trained,
# Nearest to accepted: termites, carlson, claim, lancet, godf, pebbles, ioannes, characterize,
# Nearest to smith: mormonism, insuring, functionals, germs, standout, conformist, click, auditions,
# Nearest to active: weak, bcl, translational, invalidate, offered, concretes, secrete, disparage,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8174 0.0279 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8426 0.0270 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8387 0.0268 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8169 0.0268 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8403 0.0268 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8596 0.0269 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8225 0.0268 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8342 0.0268 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8554 0.0269 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8544 0.0272 sec/batch
# Nearest to some: are, have, most, many, that, of, however, such,
# Nearest to at: years, until, the, thereafter, a, six, s, on,
# Nearest to he: his, worked, career, himself, him, after, returned, lecturer,
# Nearest to while: has, unlock, undercroft, a, most, respondents, sinc, lani,
# Nearest to states: united, schengen, in, embargo, sylvester, firearm, violated, new,
# Nearest to first: the, of, in, a, known, which, an, second,
# Nearest to or: the, is, of, used, for, a, subject, only,
# Nearest to up: them, lagging, arafura, blinds, and, chooses, average, subscripts,
# Nearest to creation: gilgamesh, creator, creationist, partnership, arithmeticae, heteroatom, numerological, existed,
# Nearest to pope: papal, papacy, popes, thirtieth, avignon, graded, cardinal, abdicating,
# Nearest to bible: kjv, hurrian, rashi, bibles, translations, hassidic, tanakh, textual,
# Nearest to liberal: meighen, fdp, conservatives, transfinite, moralities, conservative, bloc, dominion,
# Nearest to professional: wrestler, basketball, training, itil, tap, charging, stimuli, trained,
# Nearest to accepted: claim, carlson, authoritative, godf, ioannes, pebbles, mitsotakis, characterize,
# Nearest to smith: mormonism, insuring, germs, click, functionals, conformist, standout, auditions,
# Nearest to active: weak, bcl, invalidate, sive, offered, concretes, hollingworth, secrete,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8175 0.0281 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8116 0.0273 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8071 0.0270 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8044 0.0268 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8679 0.0270 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.7962 0.0269 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9632 0.0270 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8958 0.0269 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8373 0.0268 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8149 0.0269 sec/batch
# Nearest to some: are, have, most, many, that, however, of, such,
# Nearest to at: years, until, on, thereafter, six, his, s, cemac,
# Nearest to he: his, worked, career, himself, after, was, him, returned,
# Nearest to while: has, hancock, a, undercroft, respondents, unlock, fijians, most,
# Nearest to states: united, schengen, embargo, in, sylvester, firearm, kemper, violated,
# Nearest to first: the, of, in, after, which, a, second, rustin,
# Nearest to or: is, used, the, of, for, subject, a, usually,
# Nearest to up: them, arafura, and, lagging, chooses, upn, selected, corby,
# Nearest to creation: gilgamesh, creator, partnership, arithmeticae, creationist, heteroatom, exceeded, numerological,
# Nearest to pope: papal, papacy, popes, thirtieth, graded, avignon, cardinal, abdicating,
# Nearest to bible: kjv, hurrian, bibles, rashi, biblical, tanakh, textual, hassidic,
# Nearest to liberal: meighen, conservative, conservatives, fdp, moralities, transfinite, dominion, chronically,
# Nearest to professional: wrestler, basketball, training, tap, charging, mesopotamian, trained, adored,
# Nearest to accepted: carlson, joyce, ioannes, claim, authoritative, mitsotakis, lancet, godf,
# Nearest to smith: mormonism, click, insuring, germs, functionals, auditions, conformist, standout,
# Nearest to active: weak, bcl, invalidate, sive, concretes, brainwashed, disparage, hollingworth,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7430 0.0278 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8427 0.0269 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7829 0.0270 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8695 0.0270 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8133 0.0269 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8555 0.0269 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8475 0.0157 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8074 0.0270 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8651 0.0269 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8291 0.0271 sec/batch
# Nearest to some: are, have, many, that, most, however, these, such,
# Nearest to at: the, on, a, years, thereafter, until, with, to,
# Nearest to he: his, worked, himself, was, career, after, him, to,
# Nearest to while: a, hancock, unlock, undercroft, most, has, lani, fijians,
# Nearest to states: united, schengen, sylvester, firearm, in, embargo, kemper, new,
# Nearest to first: the, of, in, after, a, from, second, rustin,
# Nearest to or: the, a, is, of, used, for, although, subject,
# Nearest to up: arafura, them, took, lagging, pye, lakeview, chooses, procellariiformes,
# Nearest to creation: gilgamesh, creator, arithmeticae, partnership, heteroatom, exceeded, swing, numerological,
# Nearest to pope: papal, papacy, popes, avignon, thirtieth, graded, excommunication, abdicating,
# Nearest to bible: kjv, hurrian, bibles, rashi, tanakh, hassidic, biblical, translations,
# Nearest to liberal: meighen, fdp, conservatives, transfinite, moralities, conservative, kampuchea, chronically,
# Nearest to professional: wrestler, basketball, training, itil, mesopotamian, trained, charging, tap,
# Nearest to accepted: ioannes, joyce, carlson, lancet, termites, pebbles, godf, authoritative,
# Nearest to smith: mormonism, insuring, click, functionals, germs, conformist, scum, esdras,
# Nearest to active: weak, bcl, invalidate, concretes, offered, sive, brainwashed, disparage,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8017 0.0279 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7941 0.0269 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8028 0.0270 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7514 0.0270 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8205 0.0268 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.7996 0.0268 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8580 0.0268 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7125 0.0268 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7788 0.0269 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7823 0.0269 sec/batch
# Nearest to some: are, most, have, many, that, of, however, these,
# Nearest to at: years, on, the, a, until, six, s, thereafter,
# Nearest to he: his, worked, career, himself, him, after, returned, was,
# Nearest to while: most, has, hancock, a, unlock, semitones, undercroft, fijians,
# Nearest to states: united, schengen, embargo, in, new, nagpur, sylvester, firearm,
# Nearest to first: the, after, a, of, in, which, rustin, second,
# Nearest to or: the, of, is, a, used, although, for, are,
# Nearest to up: them, arafura, took, average, lagging, procellariiformes, household, subscripts,
# Nearest to creation: gilgamesh, partnership, creator, creationist, existed, arithmeticae, heteroatom, exceeded,
# Nearest to pope: papal, papacy, popes, avignon, thirtieth, graded, excommunication, abdicating,
# Nearest to bible: kjv, rashi, hurrian, tanakh, biblical, translations, bibles, scholars,
# Nearest to liberal: meighen, conservatives, fdp, transfinite, conservative, kampuchea, moralities, cardiff,
# Nearest to professional: wrestler, basketball, training, charging, itil, habash, medical, degree,
# Nearest to accepted: claim, carlson, joyce, godf, ioannes, termites, lancet, mitsotakis,
# Nearest to smith: mormonism, insuring, covenants, click, esdras, germs, conformist, functionals,
# Nearest to active: weak, bcl, invalidate, hollingworth, concretes, pikes, offered, secrete,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7266 0.0277 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8127 0.0269 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8194 0.0269 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8057 0.0269 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7846 0.0268 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8711 0.0269 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8184 0.0269 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8066 0.0269 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8228 0.0269 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8308 0.0269 sec/batch
# Nearest to some: are, have, most, that, many, however, of, such,
# Nearest to at: a, until, years, s, on, the, thereafter, six,
# Nearest to he: his, worked, career, himself, after, him, soon, lecturer,
# Nearest to while: has, hancock, a, most, semitones, undercroft, unlock, blvd,
# Nearest to states: united, schengen, embargo, kemper, violated, sylvester, in, firearm,
# Nearest to first: the, in, of, a, second, after, which, was,
# Nearest to or: the, is, used, of, for, a, usually, subject,
# Nearest to up: them, lagging, arafura, took, average, procellariiformes, aorta, pye,
# Nearest to creation: gilgamesh, creator, creationist, partnership, existed, arithmeticae, heteroatom, numerological,
# Nearest to pope: papal, papacy, popes, avignon, thirtieth, sancti, graded, excommunication,
# Nearest to bible: kjv, rashi, hurrian, translations, tanakh, bibles, biblical, scholars,
# Nearest to liberal: meighen, fdp, transfinite, moralities, chronically, conservative, conservatives, bloc,
# Nearest to professional: wrestler, basketball, training, itil, charging, degree, tap, habash,
# Nearest to accepted: claim, lancet, godf, carlson, termites, authoritative, vicuna, somali,
# Nearest to smith: mormonism, insuring, covenants, click, germs, functionals, rhetorica, reversing,
# Nearest to active: weak, bcl, hollingworth, invalidate, secrete, concretes, pikes, offered,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8370 0.0278 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8277 0.0268 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7894 0.0270 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8012 0.0269 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8703 0.0269 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8102 0.0269 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8126 0.0269 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8315 0.0270 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7595 0.0269 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8035 0.0268 sec/batch
# Nearest to some: are, have, most, of, that, many, however, for,
# Nearest to at: until, on, a, years, worthwhile, six, the, s,
# Nearest to he: his, career, worked, himself, him, after, was, until,
# Nearest to while: has, most, in, a, by, that, half, lani,
# Nearest to states: united, schengen, sylvester, in, embargo, new, kemper, firearm,
# Nearest to first: the, of, in, second, which, after, a, an,
# Nearest to or: the, is, used, of, for, a, usually, although,
# Nearest to up: them, lagging, arafura, spread, pye, always, aorta, today,
# Nearest to creation: gilgamesh, creator, creationist, partnership, existed, heteroatom, arithmeticae, swing,
# Nearest to pope: papal, papacy, popes, avignon, thirtieth, excommunication, graded, episcopate,
# Nearest to bible: kjv, hurrian, rashi, tanakh, translations, bibles, scholars, biblical,
# Nearest to liberal: meighen, fdp, conservative, moralities, conservatives, comfort, chronically, transfinite,
# Nearest to professional: wrestler, basketball, training, itil, charging, habash, degree, flirty,
# Nearest to accepted: claim, somali, ioannes, vicuna, forthright, sunni, godf, joyce,
# Nearest to smith: mormonism, covenants, insuring, germs, click, functionals, rhetorica, esdras,
# Nearest to active: weak, bcl, invalidate, concretes, hollingworth, sive, secrete, translational,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8552 0.0279 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7767 0.0269 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8866 0.0270 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8910 0.0269 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8509 0.0268 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8206 0.0270 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7330 0.0269 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8086 0.0268 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7230 0.0270 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8339 0.0269 sec/batch
# Nearest to some: are, have, many, most, that, however, of, for,
# Nearest to at: on, a, years, s, until, the, with, thereafter,
# Nearest to he: his, worked, career, himself, was, after, him, became,
# Nearest to while: has, a, respondents, fijians, most, less, elicited, undercroft,
# Nearest to states: united, schengen, sylvester, kemper, embargo, new, firearm, in,
# Nearest to first: the, in, of, after, second, which, a, based,
# Nearest to or: the, used, of, is, a, for, usually, subject,
# Nearest to up: them, lagging, arafura, pye, and, chooses, today, always,
# Nearest to creation: gilgamesh, heteroatom, partnership, swing, creator, exceeded, arithmeticae, relief,
# Nearest to pope: papal, papacy, popes, avignon, thirtieth, episcopate, landry, benedict,
# Nearest to bible: kjv, rashi, hurrian, bibles, translations, ulysses, tanakh, scholars,
# Nearest to liberal: meighen, moralities, chronically, comfort, conservative, fdp, bloc, simmons,
# Nearest to professional: wrestler, basketball, training, charging, tap, itil, degree, espy,
# Nearest to accepted: ioannes, claim, lancet, joyce, somali, sunni, taken, vicuna,
# Nearest to smith: mormonism, germs, insuring, covenants, click, corbijn, alberts, functionals,
# Nearest to active: weak, bcl, invalidate, sive, concretes, hollingworth, pikes, offered,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8351 0.0279 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8018 0.0271 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
