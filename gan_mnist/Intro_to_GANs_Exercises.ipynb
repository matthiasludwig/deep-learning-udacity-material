# %% [markdown]
# # Generative Adversarial Network
#
# In this notebook, we'll be building a generative adversarial network (GAN) trained on the MNIST dataset. From this, we'll be able to generate new handwritten digits!
#
# GANs were [first reported on](https://arxiv.org/abs/1406.2661) in 2014 from Ian Goodfellow and others in Yoshua Bengio's lab. Since then, GANs have exploded in popularity. Here are a few examples to check out:
#
# * [Pix2Pix](https://affinelayer.com/pixsrv/)
# * [CycleGAN](https://github.com/junyanz/CycleGAN)
# * [A whole list](https://github.com/wiseodd/generative-models)
#
# The idea behind GANs is that you have two networks, a generator $G$ and a discriminator $D$, competing against each other. The generator makes fake data to pass to the discriminator. The discriminator also sees real data and predicts if the data it's received is real or fake. The generator is trained to fool the discriminator, it wants to output data that looks _as close as possible_ to real data. And the discriminator is trained to figure out which data is real and which is fake. What ends up happening is that the generator learns to make data that is indistiguishable from real data to the discriminator.
#
# ![GAN diagram](assets/gan_diagram.png)
#
# The general structure of a GAN is shown in the diagram above, using MNIST images as data. The latent sample is a random vector the generator uses to contruct it's fake images. As the generator learns through training, it figures out how to map these random vectors to recognizable images that can fool the discriminator.
#
# The output of the discriminator is a sigmoid function, where 0 indicates a fake image and 1 indicates an real image. If you're interested only in generating new images, you can throw out the discriminator after training. Now, let's see how we build this thing in TensorFlow.

# %%
# %matplotlib inline

import pickle as pkl
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data')
# Out:
# WARNING:tensorflow:From <ipython-input-2-a37a59f11b0d>:2: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /home/ubuntu/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /home/ubuntu/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From /home/ubuntu/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From /home/ubuntu/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/ubuntu/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
print(type(mnist))
# Out:
# <class 'tensorflow.contrib.learn.python.learn.datasets.base.Datasets'>

# %% [markdown]
# ## Model Inputs
#
# First we need to create the inputs for our graph. We need two inputs, one for the discriminator and one for the generator. Here we'll call the discriminator input `inputs_real` and the generator input `inputs_z`. We'll assign them the appropriate sizes for each of the networks.
#
# >**Exercise:** Finish the `model_inputs` function below. Create the placeholders for `inputs_real` and `inputs_z` using the input sizes `real_dim` and `z_dim` respectively.

# %%
def model_inputs(real_dim, z_dim):
    inputs_real = tf.placeholder(tf.float32, (None,real_dim), name="inputs_real") # Discriminator Input
    inputs_z = tf.placeholder(tf.float32, (None,z_dim), name="inputs_z") # Generator Input
    
    return inputs_real, inputs_z

# %% [markdown]
# ## Generator network
#
# ![GAN Network](assets/gan_network.png)
#
# Here we'll build the generator network. To make this network a universal function approximator, we'll need at least one hidden layer. We should use a leaky ReLU to allow gradients to flow backwards through the layer unimpeded. A leaky ReLU is like a normal ReLU, except that there is a small non-zero output for negative input values.
#
# #### Variable Scope
# Here we need to use `tf.variable_scope` for two reasons. Firstly, we're going to make sure all the variable names start with `generator`. Similarly, we'll prepend `discriminator` to the discriminator variables. This will help out later when we're training the separate networks.
#
# We could just use `tf.name_scope` to set the names, but we also want to reuse these networks with different inputs. For the generator, we're going to train it, but also _sample from it_ as we're training and after training. The discriminator will need to share variables between the fake and real input images. So, we can use the `reuse` keyword for `tf.variable_scope` to tell TensorFlow to reuse the variables instead of creating new ones if we build the graph again.
#
# To use `tf.variable_scope`, you use a `with` statement:
# ```python
# with tf.variable_scope('scope_name', reuse=False):
#     # code here
# ```
#
# Here's more from [the TensorFlow documentation](https://www.tensorflow.org/programmers_guide/variable_scope#the_problem) to get another look at using `tf.variable_scope`.
#
# #### Leaky ReLU
# TensorFlow doesn't provide an operation for leaky ReLUs, so we'll need to make one . For this you can just take the outputs from a linear fully connected layer and pass them to `tf.maximum`. Typically, a parameter `alpha` sets the magnitude of the output for negative values. So, the output for negative input (`x`) values is `alpha*x`, and the output for positive `x` is `x`:
# $$
# f(x) = max(\alpha * x, x)
# $$
#
# #### Tanh Output
# The generator has been found to perform the best with $tanh$ for the generator output. This means that we'll have to rescale the MNIST images to be between -1 and 1, instead of 0 and 1.
#
# >**Exercise:** Implement the generator network in the function below. You'll need to return the tanh output. Make sure to wrap your code in a variable scope, with 'generator' as the scope name, and pass the `reuse` keyword argument from the function to `tf.variable_scope`.

# %%
def leaky_relu(h, alpha):
    return tf.maximum(h * alpha, h)

# %%
def generator(z, out_dim, n_units=128, reuse=False,  alpha=0.01):
    ''' Build the generator network.
    
        Arguments
        ---------
        z : Input tensor for the generator
        out_dim : Shape of the generator output
        n_units : Number of units in hidden layer
        reuse : Reuse the variables with tf.variable_scope
        alpha : leak parameter for leaky ReLU
        
        Returns
        -------
        out: 
    '''
    with tf.variable_scope('generator', reuse=reuse):
        # Hidden layer
        h1 = tf.layers.dense(z, n_units, activation=None)
        # Leaky ReLU
        h1 = leaky_relu(h1, alpha)
        
        # Logits and tanh output
        logits = tf.layers.dense(h1, out_dim, activation=None)
        out = tf.tanh(logits)
        
        return out, logits

# %% [markdown]
# ## Discriminator
#
# The discriminator network is almost exactly the same as the generator network, except that we're using a sigmoid output layer.
#
# >**Exercise:** Implement the discriminator network in the function below. Same as above, you'll need to return both the logits and the sigmoid output. Make sure to wrap your code in a variable scope, with 'discriminator' as the scope name, and pass the `reuse` keyword argument from the function arguments to `tf.variable_scope`.

# %%
def discriminator(x, n_units=128, reuse=False, alpha=0.01):
    ''' Build the discriminator network.
    
        Arguments
        ---------
        x : Input tensor for the discriminator
        n_units: Number of units in hidden layer
        reuse : Reuse the variables with tf.variable_scope
        alpha : leak parameter for leaky ReLU
        
        Returns
        -------
        out, logits: 
    '''
    with tf.variable_scope('discriminator', reuse=reuse):
        # Hidden layer
        h1 = tf.layers.dense(x, n_units, activation=None)
        # Leaky ReLU
        h1 = leaky_relu(h1, alpha)
        
        logits = tf.layers.dense(h1, 1, activation=None)
        out = tf.sigmoid(logits)
        
        return out, logits

# %% [markdown]
# ## Hyperparameters

# %%
# Size of input image to discriminator
input_size = 784 # 28x28 MNIST images flattened
# Size of latent vector to generator
z_size = 100
# Sizes of hidden layers in generator and discriminator
g_hidden_size = 128
d_hidden_size = 128
# Leak factor for leaky ReLU
alpha = 0.01
# Label smoothing 
smooth = 0.1

# %% [markdown]
# ## Build network
#
# Now we're building the network from the functions defined above.
#
# First is to get our inputs, `input_real, input_z` from `model_inputs` using the sizes of the input and z.
#
# Then, we'll create the generator, `generator(input_z, input_size)`. This builds the generator with the appropriate input and output sizes.
#
# Then the discriminators. We'll build two of them, one for real data and one for fake data. Since we want the weights to be the same for both real and fake data, we need to reuse the variables. For the fake data, we're getting it from the generator as `g_model`. So the real data discriminator is `discriminator(input_real)` while the fake discriminator is `discriminator(g_model, reuse=True)`.
#
# >**Exercise:** Build the network from the functions you defined earlier.

# %%
tf.reset_default_graph() # Wipes out graphs that were defined before
# Create our input placeholders
input_real, input_z = model_inputs(input_size, z_size) # input_real 748 long vectors since flattened

# Generator network here
g_model, g_logits = generator(input_z, input_size)
# g_model is the generator output

# Disriminator network here
d_model_real, d_logits_real = discriminator(input_real)
d_model_fake, d_logits_fake = discriminator(g_model, reuse=True)

# %% [markdown]
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses, which is a little tricky. For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_loss_real + d_loss_fake`. The losses will be sigmoid cross-entropies, which we can get with `tf.nn.sigmoid_cross_entropy_with_logits`. We'll also wrap that in `tf.reduce_mean` to get the mean for all the images in the batch. So the losses will look something like
#
# ```python
# tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=logits, labels=labels))
# ```
#
# For the real image logits, we'll use `d_logits_real` which we got from the discriminator in the cell above. For the labels, we want them to be all ones, since these are all real images. To help the discriminator generalize better, the labels are reduced a bit from 1.0 to 0.9, for example,  using the parameter `smooth`. This is known as label smoothing, typically used with classifiers to improve performance. In TensorFlow, it looks something like `labels = tf.ones_like(tensor) * (1 - smooth)`
#
# The discriminator loss for the fake data is similar. The logits are `d_logits_fake`, which we got from passing the generator output to the discriminator. These fake logits are used with labels of all zeros. Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
# Finally, the generator losses are using `d_logits_fake`, the fake image logits. But, now the labels are all ones. The generator is trying to fool the discriminator, so it wants to discriminator to output ones for fake images.
#
# >**Exercise:** Calculate the losses for the discriminator and the generator. There are two discriminator losses, one for real images and one for fake images. For the real image loss, use the real logits and (smoothed) labels of ones. For the fake image loss, use the fake logits with labels of all zeros. The total discriminator loss is the sum of those two losses. Finally, the generator loss again uses the fake logits from the discriminator, but this time the labels are all ones because the generator wants to fool the discriminator.

# %%
# Calculate losses
d_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, labels=tf.ones_like(d_logits_real) * (1 - smooth)))

d_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.zeros_like(d_logits_real)))

d_loss = d_loss_real + d_loss_fake

g_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.ones_like(d_logits_fake)))

# %% [markdown]
# ## Optimizers
#
# We want to update the generator and discriminator variables separately. So we need to get the variables for each part and build optimizers for the two parts. To get all the trainable variables, we use `tf.trainable_variables()`. This creates a list of all the variables we've defined in our graph.
#
# For the generator optimizer, we only want to generator variables. Our past selves were nice and used a variable scope to start all of our generator variable names with `generator`. So, we just need to iterate through the list from `tf.trainable_variables()` and keep variables that start with `generator`. Each variable object has an attribute `name` which holds the name of the variable as a string (`var.name == 'weights_0'` for instance).
#
# We can do something similar with the discriminator. All the variables in the discriminator start with `discriminator`.
#
# Then, in the optimizer we pass the variable lists to the `var_list` keyword argument of the `minimize` method. This tells the optimizer to only update the listed variables. Something like `tf.train.AdamOptimizer().minimize(loss, var_list=var_list)` will only train the variables in `var_list`.
#
# >**Exercise: ** Below, implement the optimizers for the generator and discriminator. First you'll need to get a list of trainable variables, then split that list into two lists, one for the generator variables and another for the discriminator variables. Finally, using `AdamOptimizer`, create an optimizer for each network that update the network variables separately.

# %%
# Optimizers
learning_rate = 0.002

# Get the trainable_variables, split into G and D parts

t_vars = tf.trainable_variables()
g_vars = [var for var in t_vars if var.name.startswith('generator')]
d_vars = [var for var in t_vars if var.name.startswith('discriminator')]

d_train_opt = tf.train.AdamOptimizer(learning_rate).minimize(d_loss, var_list=d_vars)
g_train_opt = tf.train.AdamOptimizer(learning_rate).minimize(g_loss, var_list=g_vars)

# %% [markdown]
# ## Training

# %%
batch_size = 500
epochs = 1000
samples = []
losses = []
saver = tf.train.Saver(var_list = g_vars)
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for e in range(epochs):
        for ii in range(mnist.train.num_examples//batch_size):
            batch = mnist.train.next_batch(batch_size) #batch[0] images; batch[1] labels
            
            # Get images, reshape and rescale to pass to D
            batch_images = batch[0].reshape((batch_size, 784))
            batch_images = batch_images*2 - 1 #rescale from -1 to 1
            
            # Sample random noise for G
            batch_z = np.random.uniform(-1, 1, size=(batch_size, z_size)) #random noise from -1 to 1
            
            # Run optimizers
            _ = sess.run(d_train_opt, feed_dict={input_real: batch_images, input_z: batch_z})
            _ = sess.run(g_train_opt, feed_dict={input_z: batch_z})
        
        # At the end of each epoch, get the losses and print them out
        train_loss_d = sess.run(d_loss, {input_z: batch_z, input_real: batch_images})
        train_loss_g = g_loss.eval({input_z: batch_z})
            
        print("Epoch {}/{}...".format(e+1, epochs),
              "Discriminator Loss: {:.4f}...".format(train_loss_d),
              "Generator Loss: {:.4f}".format(train_loss_g))    
        # Save losses to view after training
        losses.append((train_loss_d, train_loss_g))
        
        # Sample from generator as we're training for viewing afterwards
        sample_z = np.random.uniform(-1, 1, size=(16, z_size))
        gen_samples = sess.run(
                       generator(input_z, input_size, n_units=g_hidden_size, reuse=True, alpha=alpha),
                       feed_dict={input_z: sample_z})
        samples.append(gen_samples)
        saver.save(sess, './checkpoints/generator.ckpt')

# Save training generator samples
with open('train_samples.pkl', 'wb') as f:
    pkl.dump(samples, f)
# Out:
# Epoch 1/1000... Discriminator Loss: 0.4357... Generator Loss: 2.5263
# Epoch 2/1000... Discriminator Loss: 0.4881... Generator Loss: 1.9869
# Epoch 3/1000... Discriminator Loss: 0.3994... Generator Loss: 2.9211
# Epoch 4/1000... Discriminator Loss: 0.3648... Generator Loss: 3.8666
# Epoch 5/1000... Discriminator Loss: 0.3573... Generator Loss: 4.2038
# Epoch 6/1000... Discriminator Loss: 0.3449... Generator Loss: 4.4831
# Epoch 7/1000... Discriminator Loss: 0.7307... Generator Loss: 1.9487
# Epoch 8/1000... Discriminator Loss: 1.0362... Generator Loss: 1.0389
# Epoch 9/1000... Discriminator Loss: 0.5792... Generator Loss: 2.8590
# Epoch 10/1000... Discriminator Loss: 0.5825... Generator Loss: 2.6083
# Epoch 11/1000... Discriminator Loss: 0.7581... Generator Loss: 2.7190
# Epoch 12/1000... Discriminator Loss: 1.7601... Generator Loss: 2.2357
# Epoch 13/1000... Discriminator Loss: 1.0839... Generator Loss: 2.2236
# Epoch 14/1000... Discriminator Loss: 0.7362... Generator Loss: 7.5122
# Epoch 15/1000... Discriminator Loss: 0.5549... Generator Loss: 4.9555
# Epoch 16/1000... Discriminator Loss: 1.7282... Generator Loss: 3.4492
# Epoch 17/1000... Discriminator Loss: 2.5330... Generator Loss: 3.1893
# Epoch 18/1000... Discriminator Loss: 0.9475... Generator Loss: 5.8656
# Epoch 19/1000... Discriminator Loss: 1.0012... Generator Loss: 2.4548
# Epoch 20/1000... Discriminator Loss: 1.0657... Generator Loss: 3.8226
# Epoch 21/1000... Discriminator Loss: 1.8538... Generator Loss: 3.0092
# Epoch 22/1000... Discriminator Loss: 1.1661... Generator Loss: 3.3601
# Epoch 23/1000... Discriminator Loss: 1.4773... Generator Loss: 4.1812
# Epoch 24/1000... Discriminator Loss: 0.8816... Generator Loss: 2.6133
# Epoch 25/1000... Discriminator Loss: 0.6323... Generator Loss: 3.1883
# Epoch 26/1000... Discriminator Loss: 1.0835... Generator Loss: 2.5389
# Epoch 27/1000... Discriminator Loss: 0.7558... Generator Loss: 3.3186
# Epoch 28/1000... Discriminator Loss: 0.8728... Generator Loss: 4.3908
# Epoch 29/1000... Discriminator Loss: 1.3423... Generator Loss: 3.3942
# Epoch 30/1000... Discriminator Loss: 0.8440... Generator Loss: 2.6863
# Epoch 31/1000... Discriminator Loss: 0.8452... Generator Loss: 2.3072
# Epoch 32/1000... Discriminator Loss: 1.0202... Generator Loss: 2.2281
# Epoch 33/1000... Discriminator Loss: 0.6433... Generator Loss: 2.7179
# Epoch 34/1000... Discriminator Loss: 0.8202... Generator Loss: 2.4269
# Epoch 35/1000... Discriminator Loss: 1.2103... Generator Loss: 2.0894
# Epoch 36/1000... Discriminator Loss: 1.0667... Generator Loss: 1.5991
# Epoch 37/1000... Discriminator Loss: 1.8143... Generator Loss: 4.1432
# Epoch 38/1000... Discriminator Loss: 0.8327... Generator Loss: 2.2715
# Epoch 39/1000... Discriminator Loss: 1.0394... Generator Loss: 3.1603
# Epoch 40/1000... Discriminator Loss: 2.9598... Generator Loss: 4.5764
# Epoch 41/1000... Discriminator Loss: 1.2498... Generator Loss: 2.0961
# Epoch 42/1000... Discriminator Loss: 1.0556... Generator Loss: 3.0549
# Epoch 43/1000... Discriminator Loss: 1.1990... Generator Loss: 2.5364
# Epoch 44/1000... Discriminator Loss: 1.1033... Generator Loss: 2.3817
# Epoch 45/1000... Discriminator Loss: 0.9702... Generator Loss: 7.0621
# Epoch 46/1000... Discriminator Loss: 1.6777... Generator Loss: 4.0867
# Epoch 47/1000... Discriminator Loss: 2.8700... Generator Loss: 3.7814
# Epoch 48/1000... Discriminator Loss: 1.1766... Generator Loss: 2.2952
# Epoch 49/1000... Discriminator Loss: 0.8738... Generator Loss: 2.6899
# Epoch 50/1000... Discriminator Loss: 1.3684... Generator Loss: 4.4570
# Epoch 51/1000... Discriminator Loss: 1.1544... Generator Loss: 2.5901
# Epoch 52/1000... Discriminator Loss: 1.2191... Generator Loss: 3.1964
# Epoch 53/1000... Discriminator Loss: 1.1454... Generator Loss: 2.7790
# Epoch 54/1000... Discriminator Loss: 0.9280... Generator Loss: 2.6435
# Epoch 55/1000... Discriminator Loss: 1.3213... Generator Loss: 2.8661
# Epoch 56/1000... Discriminator Loss: 1.8607... Generator Loss: 2.5527
# Epoch 57/1000... Discriminator Loss: 1.8967... Generator Loss: 4.1322
# Epoch 58/1000... Discriminator Loss: 1.1819... Generator Loss: 1.5898
# Epoch 59/1000... Discriminator Loss: 0.9711... Generator Loss: 3.8362
# Epoch 60/1000... Discriminator Loss: 1.1720... Generator Loss: 2.8911
# Epoch 61/1000... Discriminator Loss: 1.9224... Generator Loss: 2.4638
# Epoch 62/1000... Discriminator Loss: 0.9322... Generator Loss: 2.1732
# Epoch 63/1000... Discriminator Loss: 0.9859... Generator Loss: 2.3542
# Epoch 64/1000... Discriminator Loss: 1.8652... Generator Loss: 0.9504
# Epoch 65/1000... Discriminator Loss: 2.9534... Generator Loss: 1.2581
# Epoch 66/1000... Discriminator Loss: 1.1319... Generator Loss: 3.2754
# Epoch 67/1000... Discriminator Loss: 1.7397... Generator Loss: 3.7629
# Epoch 68/1000... Discriminator Loss: 1.5988... Generator Loss: 2.2774
# Epoch 69/1000... Discriminator Loss: 1.6521... Generator Loss: 2.1474
# Epoch 70/1000... Discriminator Loss: 1.5930... Generator Loss: 1.4556
# Epoch 71/1000... Discriminator Loss: 1.3328... Generator Loss: 2.2152
# Epoch 72/1000... Discriminator Loss: 1.0307... Generator Loss: 1.8128
# Epoch 73/1000... Discriminator Loss: 1.6100... Generator Loss: 2.9536
# Epoch 74/1000... Discriminator Loss: 1.2681... Generator Loss: 1.9379
# Epoch 75/1000... Discriminator Loss: 2.2157... Generator Loss: 1.1711
# Epoch 76/1000... Discriminator Loss: 1.4252... Generator Loss: 1.8403
# Epoch 77/1000... Discriminator Loss: 0.7717... Generator Loss: 2.1229
# Epoch 78/1000... Discriminator Loss: 0.7201... Generator Loss: 3.4977
# Epoch 79/1000... Discriminator Loss: 1.5992... Generator Loss: 1.5758
# Epoch 80/1000... Discriminator Loss: 0.8357... Generator Loss: 2.3519
# Epoch 81/1000... Discriminator Loss: 1.1981... Generator Loss: 1.9573
# Epoch 82/1000... Discriminator Loss: 1.0770... Generator Loss: 2.4327
# Epoch 83/1000... Discriminator Loss: 1.1113... Generator Loss: 2.6575
# Epoch 84/1000... Discriminator Loss: 1.4502... Generator Loss: 4.7605
# Epoch 85/1000... Discriminator Loss: 0.9785... Generator Loss: 2.1385
# Epoch 86/1000... Discriminator Loss: 2.8816... Generator Loss: 1.7360
# Epoch 87/1000... Discriminator Loss: 2.3001... Generator Loss: 1.5534
# Epoch 88/1000... Discriminator Loss: 1.3957... Generator Loss: 1.6819
# Epoch 89/1000... Discriminator Loss: 1.2079... Generator Loss: 2.0175
# Epoch 90/1000... Discriminator Loss: 1.0492... Generator Loss: 3.5922
# Epoch 91/1000... Discriminator Loss: 1.1236... Generator Loss: 2.3712
# Epoch 92/1000... Discriminator Loss: 0.7080... Generator Loss: 2.4634
# Epoch 93/1000... Discriminator Loss: 1.5829... Generator Loss: 2.0299
# Epoch 94/1000... Discriminator Loss: 1.1457... Generator Loss: 1.9299
# Epoch 95/1000... Discriminator Loss: 0.9886... Generator Loss: 2.0240
# Epoch 96/1000... Discriminator Loss: 1.1625... Generator Loss: 1.4807
# Epoch 97/1000... Discriminator Loss: 0.8544... Generator Loss: 3.5009
# Epoch 98/1000... Discriminator Loss: 0.9183... Generator Loss: 2.2681
# Epoch 99/1000... Discriminator Loss: 1.2904... Generator Loss: 1.9753
# Epoch 100/1000... Discriminator Loss: 1.5281... Generator Loss: 1.7635
# Epoch 101/1000... Discriminator Loss: 1.3337... Generator Loss: 2.3785
# Epoch 102/1000... Discriminator Loss: 1.7519... Generator Loss: 2.1947
# Epoch 103/1000... Discriminator Loss: 1.0388... Generator Loss: 1.8269
# Epoch 104/1000... Discriminator Loss: 1.2014... Generator Loss: 1.9023
# Epoch 105/1000... Discriminator Loss: 1.0791... Generator Loss: 2.7717
# Epoch 106/1000... Discriminator Loss: 1.0772... Generator Loss: 2.0032
# Epoch 107/1000... Discriminator Loss: 1.0285... Generator Loss: 2.7263
# Epoch 108/1000... Discriminator Loss: 1.0037... Generator Loss: 3.3737
# Epoch 109/1000... Discriminator Loss: 1.1005... Generator Loss: 2.7571
# Epoch 110/1000... Discriminator Loss: 1.1453... Generator Loss: 2.3648
# Epoch 111/1000... Discriminator Loss: 1.2037... Generator Loss: 1.5653
# Epoch 112/1000... Discriminator Loss: 1.4006... Generator Loss: 2.3121
# Epoch 113/1000... Discriminator Loss: 0.8806... Generator Loss: 2.5978
# Epoch 114/1000... Discriminator Loss: 1.1636... Generator Loss: 2.3489
# Epoch 115/1000... Discriminator Loss: 0.8658... Generator Loss: 3.0596
# Epoch 116/1000... Discriminator Loss: 1.0634... Generator Loss: 2.0111
# Epoch 117/1000... Discriminator Loss: 1.1839... Generator Loss: 1.8645
# Epoch 118/1000... Discriminator Loss: 0.8402... Generator Loss: 2.0606
# Epoch 119/1000... Discriminator Loss: 1.3760... Generator Loss: 2.4458
# Epoch 120/1000... Discriminator Loss: 1.2773... Generator Loss: 2.5758
# Epoch 121/1000... Discriminator Loss: 1.2196... Generator Loss: 2.6218
# Epoch 122/1000... Discriminator Loss: 0.7663... Generator Loss: 2.3087
# Epoch 123/1000... Discriminator Loss: 0.8459... Generator Loss: 2.0856
# Epoch 124/1000... Discriminator Loss: 0.8325... Generator Loss: 2.8390
# Epoch 125/1000... Discriminator Loss: 0.7916... Generator Loss: 2.9140
# Epoch 126/1000... Discriminator Loss: 0.9074... Generator Loss: 3.1805
# Epoch 127/1000... Discriminator Loss: 0.8855... Generator Loss: 2.0169
# Epoch 128/1000... Discriminator Loss: 1.0727... Generator Loss: 2.0911
# Epoch 129/1000... Discriminator Loss: 1.1074... Generator Loss: 2.7013
# Epoch 130/1000... Discriminator Loss: 0.8704... Generator Loss: 3.2981
# Epoch 131/1000... Discriminator Loss: 0.8269... Generator Loss: 2.6419
# Epoch 132/1000... Discriminator Loss: 0.7932... Generator Loss: 3.3251
# Epoch 133/1000... Discriminator Loss: 0.8906... Generator Loss: 2.2557
# Epoch 134/1000... Discriminator Loss: 0.8677... Generator Loss: 2.2648
# Epoch 135/1000... Discriminator Loss: 0.9669... Generator Loss: 2.0693
# Epoch 136/1000... Discriminator Loss: 0.7887... Generator Loss: 2.5299
# Epoch 137/1000... Discriminator Loss: 0.8089... Generator Loss: 2.1023
# Epoch 138/1000... Discriminator Loss: 1.1417... Generator Loss: 1.8744
# Epoch 139/1000... Discriminator Loss: 0.8600... Generator Loss: 3.1987
# Epoch 140/1000... Discriminator Loss: 1.0852... Generator Loss: 2.2671
# Epoch 141/1000... Discriminator Loss: 1.2520... Generator Loss: 2.4760
# Epoch 142/1000... Discriminator Loss: 0.9273... Generator Loss: 2.0899
# Epoch 143/1000... Discriminator Loss: 0.9800... Generator Loss: 1.7833
# Epoch 144/1000... Discriminator Loss: 0.9956... Generator Loss: 2.2354
# Epoch 145/1000... Discriminator Loss: 1.1117... Generator Loss: 2.2301
# Epoch 146/1000... Discriminator Loss: 0.9370... Generator Loss: 1.9551
# Epoch 147/1000... Discriminator Loss: 1.4069... Generator Loss: 2.0395
# Epoch 148/1000... Discriminator Loss: 1.5818... Generator Loss: 1.2663
# Epoch 149/1000... Discriminator Loss: 1.0384... Generator Loss: 3.3190
# Epoch 150/1000... Discriminator Loss: 0.9901... Generator Loss: 2.2391
# Epoch 151/1000... Discriminator Loss: 1.1691... Generator Loss: 1.7918
# Epoch 152/1000... Discriminator Loss: 0.9257... Generator Loss: 1.6811
# Epoch 153/1000... Discriminator Loss: 0.8707... Generator Loss: 2.6405
# Epoch 154/1000... Discriminator Loss: 1.0799... Generator Loss: 1.7544
# Epoch 155/1000... Discriminator Loss: 1.0790... Generator Loss: 2.1720
# Epoch 156/1000... Discriminator Loss: 0.7850... Generator Loss: 2.9534
# Epoch 157/1000... Discriminator Loss: 0.9302... Generator Loss: 2.2369
# Epoch 158/1000... Discriminator Loss: 0.8689... Generator Loss: 2.4755
# Epoch 159/1000... Discriminator Loss: 1.1983... Generator Loss: 2.0342
# Epoch 160/1000... Discriminator Loss: 0.8029... Generator Loss: 3.4424
# Epoch 161/1000... Discriminator Loss: 0.9535... Generator Loss: 3.2418
# Epoch 162/1000... Discriminator Loss: 0.8669... Generator Loss: 2.1547
# Epoch 163/1000... Discriminator Loss: 1.0167... Generator Loss: 2.7044
# Epoch 164/1000... Discriminator Loss: 0.9602... Generator Loss: 2.2262
# Epoch 165/1000... Discriminator Loss: 0.8559... Generator Loss: 2.6991
# Epoch 166/1000... Discriminator Loss: 1.0502... Generator Loss: 1.9021
# Epoch 167/1000... Discriminator Loss: 1.3021... Generator Loss: 2.2063
# Epoch 168/1000... Discriminator Loss: 1.2115... Generator Loss: 2.1006
# Epoch 169/1000... Discriminator Loss: 0.9773... Generator Loss: 2.5307
# Epoch 170/1000... Discriminator Loss: 0.9205... Generator Loss: 1.7964
# Epoch 171/1000... Discriminator Loss: 0.9659... Generator Loss: 2.5272
# Epoch 172/1000... Discriminator Loss: 1.0688... Generator Loss: 2.7742
# Epoch 173/1000... Discriminator Loss: 0.9072... Generator Loss: 2.4832
# Epoch 174/1000... Discriminator Loss: 1.0308... Generator Loss: 2.4681
# Epoch 175/1000... Discriminator Loss: 0.7726... Generator Loss: 2.8764
# Epoch 176/1000... Discriminator Loss: 0.8844... Generator Loss: 2.8246
# Epoch 177/1000... Discriminator Loss: 0.9707... Generator Loss: 2.3475
# Epoch 178/1000... Discriminator Loss: 0.8776... Generator Loss: 2.2759
# Epoch 179/1000... Discriminator Loss: 0.8526... Generator Loss: 2.3514
# Epoch 180/1000... Discriminator Loss: 0.9508... Generator Loss: 2.3103
# Epoch 181/1000... Discriminator Loss: 0.9765... Generator Loss: 1.9534
# Epoch 182/1000... Discriminator Loss: 0.8155... Generator Loss: 2.3951
# Epoch 183/1000... Discriminator Loss: 0.8634... Generator Loss: 2.6441
# Epoch 184/1000... Discriminator Loss: 0.9831... Generator Loss: 1.8818
# Epoch 185/1000... Discriminator Loss: 0.8708... Generator Loss: 2.2472
# Epoch 186/1000... Discriminator Loss: 0.8005... Generator Loss: 2.6087
# Epoch 187/1000... Discriminator Loss: 0.9533... Generator Loss: 2.3969
# Epoch 188/1000... Discriminator Loss: 0.9758... Generator Loss: 1.7002
# Epoch 189/1000... Discriminator Loss: 0.9000... Generator Loss: 2.3332
# Epoch 190/1000... Discriminator Loss: 1.2252... Generator Loss: 2.5143
# Epoch 191/1000... Discriminator Loss: 1.0638... Generator Loss: 2.2229
# Epoch 192/1000... Discriminator Loss: 1.0134... Generator Loss: 2.0937
# Epoch 193/1000... Discriminator Loss: 0.8715... Generator Loss: 2.3909
# Epoch 194/1000... Discriminator Loss: 0.9813... Generator Loss: 3.3260
# Epoch 195/1000... Discriminator Loss: 0.7478... Generator Loss: 2.8676
# Epoch 196/1000... Discriminator Loss: 1.0292... Generator Loss: 2.3695
# Epoch 197/1000... Discriminator Loss: 0.9745... Generator Loss: 2.0226
# Epoch 198/1000... Discriminator Loss: 0.9889... Generator Loss: 2.4556
# Epoch 199/1000... Discriminator Loss: 1.1301... Generator Loss: 2.7091
# Epoch 200/1000... Discriminator Loss: 1.2865... Generator Loss: 2.1826
# Epoch 201/1000... Discriminator Loss: 0.8567... Generator Loss: 2.1822
# Epoch 202/1000... Discriminator Loss: 1.0398... Generator Loss: 2.7572
# Epoch 203/1000... Discriminator Loss: 1.0805... Generator Loss: 1.7628
# Epoch 204/1000... Discriminator Loss: 0.9660... Generator Loss: 2.1236
# Epoch 205/1000... Discriminator Loss: 1.0518... Generator Loss: 2.5175
# Epoch 206/1000... Discriminator Loss: 1.0620... Generator Loss: 2.5572
# Epoch 207/1000... Discriminator Loss: 0.9625... Generator Loss: 2.2847
# Epoch 208/1000... Discriminator Loss: 1.0018... Generator Loss: 1.8714
# Epoch 209/1000... Discriminator Loss: 0.9253... Generator Loss: 2.2566
# Epoch 210/1000... Discriminator Loss: 1.1792... Generator Loss: 1.9869
# Epoch 211/1000... Discriminator Loss: 1.0225... Generator Loss: 2.0546
# Epoch 212/1000... Discriminator Loss: 1.0657... Generator Loss: 1.9711
# Epoch 213/1000... Discriminator Loss: 0.8772... Generator Loss: 2.5295
# Epoch 214/1000... Discriminator Loss: 0.9073... Generator Loss: 2.1335
# Epoch 215/1000... Discriminator Loss: 0.9008... Generator Loss: 2.3386
# Epoch 216/1000... Discriminator Loss: 0.8711... Generator Loss: 2.1459
# Epoch 217/1000... Discriminator Loss: 0.9980... Generator Loss: 1.6505
# Epoch 218/1000... Discriminator Loss: 1.0167... Generator Loss: 2.1881
# Epoch 219/1000... Discriminator Loss: 1.0849... Generator Loss: 2.5236
# Epoch 220/1000... Discriminator Loss: 1.1432... Generator Loss: 2.3098
# Epoch 221/1000... Discriminator Loss: 1.0088... Generator Loss: 2.5353
# Epoch 222/1000... Discriminator Loss: 1.1330... Generator Loss: 2.2216
# Epoch 223/1000... Discriminator Loss: 0.9626... Generator Loss: 2.0537
# Epoch 224/1000... Discriminator Loss: 1.1411... Generator Loss: 1.6803
# Epoch 225/1000... Discriminator Loss: 0.9850... Generator Loss: 2.0059
# Epoch 226/1000... Discriminator Loss: 0.9675... Generator Loss: 2.1354
# Epoch 227/1000... Discriminator Loss: 0.9561... Generator Loss: 1.9666
# Epoch 228/1000... Discriminator Loss: 0.8573... Generator Loss: 2.2668
# Epoch 229/1000... Discriminator Loss: 0.7996... Generator Loss: 2.3286
# Epoch 230/1000... Discriminator Loss: 0.9021... Generator Loss: 2.3261
# Epoch 231/1000... Discriminator Loss: 0.8771... Generator Loss: 2.4677
# Epoch 232/1000... Discriminator Loss: 0.9970... Generator Loss: 1.9844
# Epoch 233/1000... Discriminator Loss: 0.8828... Generator Loss: 3.1044
# Epoch 234/1000... Discriminator Loss: 0.8463... Generator Loss: 2.4413
# Epoch 235/1000... Discriminator Loss: 0.8685... Generator Loss: 2.3353
# Epoch 236/1000... Discriminator Loss: 0.8974... Generator Loss: 3.1349
# Epoch 237/1000... Discriminator Loss: 0.8618... Generator Loss: 2.4560
# Epoch 238/1000... Discriminator Loss: 1.0219... Generator Loss: 1.9816
# Epoch 239/1000... Discriminator Loss: 0.9443... Generator Loss: 2.2447
# Epoch 240/1000... Discriminator Loss: 1.1315... Generator Loss: 1.9623
# Epoch 241/1000... Discriminator Loss: 0.8152... Generator Loss: 2.5328
# Epoch 242/1000... Discriminator Loss: 0.7827... Generator Loss: 2.2405
# Epoch 243/1000... Discriminator Loss: 0.8574... Generator Loss: 2.0708
# Epoch 244/1000... Discriminator Loss: 0.7807... Generator Loss: 2.3147
# Epoch 245/1000... Discriminator Loss: 0.8723... Generator Loss: 3.1578
# Epoch 246/1000... Discriminator Loss: 1.0321... Generator Loss: 2.5245
# Epoch 247/1000... Discriminator Loss: 0.9626... Generator Loss: 1.7762
# Epoch 248/1000... Discriminator Loss: 0.9893... Generator Loss: 1.6388
# Epoch 249/1000... Discriminator Loss: 1.0112... Generator Loss: 2.2393
# Epoch 250/1000... Discriminator Loss: 0.8643... Generator Loss: 2.4169
# Epoch 251/1000... Discriminator Loss: 1.0349... Generator Loss: 2.1002
# Epoch 252/1000... Discriminator Loss: 0.9885... Generator Loss: 1.8628
# Epoch 253/1000... Discriminator Loss: 0.9286... Generator Loss: 2.2952
# Epoch 254/1000... Discriminator Loss: 0.8318... Generator Loss: 2.4446
# Epoch 255/1000... Discriminator Loss: 0.9152... Generator Loss: 2.3666
# Epoch 256/1000... Discriminator Loss: 0.9604... Generator Loss: 2.1801
# Epoch 257/1000... Discriminator Loss: 0.9057... Generator Loss: 2.2426
# Epoch 258/1000... Discriminator Loss: 0.8163... Generator Loss: 2.5422
# Epoch 259/1000... Discriminator Loss: 1.1175... Generator Loss: 1.9692
# Epoch 260/1000... Discriminator Loss: 0.9253... Generator Loss: 2.1660
# Epoch 261/1000... Discriminator Loss: 0.9680... Generator Loss: 2.2569
# Epoch 262/1000... Discriminator Loss: 0.9380... Generator Loss: 2.1671
# Epoch 263/1000... Discriminator Loss: 0.9147... Generator Loss: 2.6338
# Epoch 264/1000... Discriminator Loss: 0.7888... Generator Loss: 2.6312
# Epoch 265/1000... Discriminator Loss: 0.9260... Generator Loss: 2.0655
# Epoch 266/1000... Discriminator Loss: 0.7741... Generator Loss: 2.9814
# Epoch 267/1000... Discriminator Loss: 1.0110... Generator Loss: 2.2510
# Epoch 268/1000... Discriminator Loss: 0.9118... Generator Loss: 1.9972
# Epoch 269/1000... Discriminator Loss: 1.0633... Generator Loss: 2.4159
# Epoch 270/1000... Discriminator Loss: 0.9669... Generator Loss: 2.3807
# Epoch 271/1000... Discriminator Loss: 0.8582... Generator Loss: 2.5953
# Epoch 272/1000... Discriminator Loss: 0.8735... Generator Loss: 2.0661
# Epoch 273/1000... Discriminator Loss: 0.9876... Generator Loss: 2.1102
# Epoch 274/1000... Discriminator Loss: 0.9948... Generator Loss: 1.9496
# Epoch 275/1000... Discriminator Loss: 0.8533... Generator Loss: 2.1956
# Epoch 276/1000... Discriminator Loss: 0.9790... Generator Loss: 1.9977
# Epoch 277/1000... Discriminator Loss: 0.9996... Generator Loss: 2.1732
# Epoch 278/1000... Discriminator Loss: 0.8158... Generator Loss: 1.9797
# Epoch 279/1000... Discriminator Loss: 0.8559... Generator Loss: 2.0588
# Epoch 280/1000... Discriminator Loss: 0.9399... Generator Loss: 1.9905
# Epoch 281/1000... Discriminator Loss: 0.8831... Generator Loss: 2.2987
# Epoch 282/1000... Discriminator Loss: 0.8529... Generator Loss: 2.3846
# Epoch 283/1000... Discriminator Loss: 0.8127... Generator Loss: 2.3632
# Epoch 284/1000... Discriminator Loss: 0.8720... Generator Loss: 2.1414
# Epoch 285/1000... Discriminator Loss: 1.0134... Generator Loss: 1.7824
# Epoch 286/1000... Discriminator Loss: 0.9122... Generator Loss: 2.0728
# Epoch 287/1000... Discriminator Loss: 0.8403... Generator Loss: 2.7253
# Epoch 288/1000... Discriminator Loss: 0.9275... Generator Loss: 2.1575
# Epoch 289/1000... Discriminator Loss: 0.7578... Generator Loss: 2.4870
# Epoch 290/1000... Discriminator Loss: 1.0597... Generator Loss: 2.5004
# Epoch 291/1000... Discriminator Loss: 0.8214... Generator Loss: 2.5619
# Epoch 292/1000... Discriminator Loss: 0.7370... Generator Loss: 2.5272
# Epoch 293/1000... Discriminator Loss: 0.9776... Generator Loss: 2.0217
# Epoch 294/1000... Discriminator Loss: 0.8852... Generator Loss: 2.2473
# Epoch 295/1000... Discriminator Loss: 0.9842... Generator Loss: 2.0796
# Epoch 296/1000... Discriminator Loss: 0.9588... Generator Loss: 2.0926
# Epoch 297/1000... Discriminator Loss: 0.9851... Generator Loss: 2.1162
# Epoch 298/1000... Discriminator Loss: 0.8510... Generator Loss: 1.9719
# Epoch 299/1000... Discriminator Loss: 0.8725... Generator Loss: 2.1631
# Epoch 300/1000... Discriminator Loss: 0.9435... Generator Loss: 2.0469
# Epoch 301/1000... Discriminator Loss: 0.8206... Generator Loss: 2.3150
# Epoch 302/1000... Discriminator Loss: 0.7676... Generator Loss: 2.1990
# Epoch 303/1000... Discriminator Loss: 0.8610... Generator Loss: 2.5066
# Epoch 304/1000... Discriminator Loss: 0.7317... Generator Loss: 2.7068
# Epoch 305/1000... Discriminator Loss: 0.7502... Generator Loss: 2.4742
# Epoch 306/1000... Discriminator Loss: 0.9870... Generator Loss: 1.9659
# Epoch 307/1000... Discriminator Loss: 0.8236... Generator Loss: 2.0250
# Epoch 308/1000... Discriminator Loss: 0.9311... Generator Loss: 2.3949
# Epoch 309/1000... Discriminator Loss: 0.9276... Generator Loss: 2.5780
# Epoch 310/1000... Discriminator Loss: 0.8814... Generator Loss: 2.3854
# Epoch 311/1000... Discriminator Loss: 0.7641... Generator Loss: 2.4636
# Epoch 312/1000... Discriminator Loss: 1.0315... Generator Loss: 2.0262
# Epoch 313/1000... Discriminator Loss: 0.8546... Generator Loss: 2.1814
# Epoch 314/1000... Discriminator Loss: 0.9006... Generator Loss: 2.1537
# Epoch 315/1000... Discriminator Loss: 0.8405... Generator Loss: 2.1197
# Epoch 316/1000... Discriminator Loss: 0.9112... Generator Loss: 1.9372
# Epoch 317/1000... Discriminator Loss: 0.9712... Generator Loss: 2.0921
# Epoch 318/1000... Discriminator Loss: 0.9638... Generator Loss: 2.2826
# Epoch 319/1000... Discriminator Loss: 0.9175... Generator Loss: 2.0539
# Epoch 320/1000... Discriminator Loss: 0.8877... Generator Loss: 1.9280
# Epoch 321/1000... Discriminator Loss: 0.8710... Generator Loss: 2.2544
# Epoch 322/1000... Discriminator Loss: 0.8671... Generator Loss: 2.0051
# Epoch 323/1000... Discriminator Loss: 1.1087... Generator Loss: 1.5635
# Epoch 324/1000... Discriminator Loss: 0.9257... Generator Loss: 2.1316
# Epoch 325/1000... Discriminator Loss: 0.8732... Generator Loss: 2.4614
# Epoch 326/1000... Discriminator Loss: 1.0089... Generator Loss: 1.6943
# Epoch 327/1000... Discriminator Loss: 0.9915... Generator Loss: 1.8030
# Epoch 328/1000... Discriminator Loss: 0.9033... Generator Loss: 2.1004
# Epoch 329/1000... Discriminator Loss: 0.9285... Generator Loss: 1.9480
# Epoch 330/1000... Discriminator Loss: 0.9057... Generator Loss: 1.9818
# Epoch 331/1000... Discriminator Loss: 0.9009... Generator Loss: 2.3276
# Epoch 332/1000... Discriminator Loss: 0.9158... Generator Loss: 2.1226
# Epoch 333/1000... Discriminator Loss: 0.8635... Generator Loss: 2.0797
# Epoch 334/1000... Discriminator Loss: 0.7995... Generator Loss: 2.1904
# Epoch 335/1000... Discriminator Loss: 1.0153... Generator Loss: 2.5044
# Epoch 336/1000... Discriminator Loss: 0.9501... Generator Loss: 1.9988
# Epoch 337/1000... Discriminator Loss: 0.9623... Generator Loss: 2.3856
# Epoch 338/1000... Discriminator Loss: 0.8692... Generator Loss: 2.1248
# Epoch 339/1000... Discriminator Loss: 0.8955... Generator Loss: 2.4538
# Epoch 340/1000... Discriminator Loss: 0.9629... Generator Loss: 2.0057
# Epoch 341/1000... Discriminator Loss: 0.8747... Generator Loss: 2.2403
# Epoch 342/1000... Discriminator Loss: 0.9226... Generator Loss: 2.3800
# Epoch 343/1000... Discriminator Loss: 0.9088... Generator Loss: 2.0080
# Epoch 344/1000... Discriminator Loss: 0.9993... Generator Loss: 1.7545
# Epoch 345/1000... Discriminator Loss: 0.8514... Generator Loss: 2.1331
# Epoch 346/1000... Discriminator Loss: 0.9158... Generator Loss: 1.9066
# Epoch 347/1000... Discriminator Loss: 0.9207... Generator Loss: 2.0897
# Epoch 348/1000... Discriminator Loss: 1.0069... Generator Loss: 1.9509
# Epoch 349/1000... Discriminator Loss: 0.9186... Generator Loss: 2.1974
# Epoch 350/1000... Discriminator Loss: 0.8931... Generator Loss: 2.1869
# Epoch 351/1000... Discriminator Loss: 0.8878... Generator Loss: 2.2328
# Epoch 352/1000... Discriminator Loss: 1.0059... Generator Loss: 2.1563
# Epoch 353/1000... Discriminator Loss: 0.8312... Generator Loss: 2.0566
# Epoch 354/1000... Discriminator Loss: 0.9272... Generator Loss: 2.0354
# Epoch 355/1000... Discriminator Loss: 0.9549... Generator Loss: 1.8598
# Epoch 356/1000... Discriminator Loss: 0.8671... Generator Loss: 2.0678
# Epoch 357/1000... Discriminator Loss: 0.9198... Generator Loss: 1.9390
# Epoch 358/1000... Discriminator Loss: 0.7731... Generator Loss: 2.6264
# Epoch 359/1000... Discriminator Loss: 0.8549... Generator Loss: 2.3702
# Epoch 360/1000... Discriminator Loss: 0.9137... Generator Loss: 2.1221
# Epoch 361/1000... Discriminator Loss: 0.8921... Generator Loss: 2.0321
# Epoch 362/1000... Discriminator Loss: 0.9337... Generator Loss: 1.8452
# Epoch 363/1000... Discriminator Loss: 0.9042... Generator Loss: 2.0557
# Epoch 364/1000... Discriminator Loss: 0.9105... Generator Loss: 1.8767
# Epoch 365/1000... Discriminator Loss: 0.9747... Generator Loss: 2.0351
# Epoch 366/1000... Discriminator Loss: 0.9406... Generator Loss: 1.7310
# Epoch 367/1000... Discriminator Loss: 0.8942... Generator Loss: 2.2436
# Epoch 368/1000... Discriminator Loss: 0.9100... Generator Loss: 1.8114
# Epoch 369/1000... Discriminator Loss: 0.8093... Generator Loss: 2.1588
# Epoch 370/1000... Discriminator Loss: 0.8139... Generator Loss: 2.2397
# Epoch 371/1000... Discriminator Loss: 0.9834... Generator Loss: 1.9181
# Epoch 372/1000... Discriminator Loss: 0.9826... Generator Loss: 1.8865
# Epoch 373/1000... Discriminator Loss: 0.7637... Generator Loss: 2.8871
# Epoch 374/1000... Discriminator Loss: 0.8626... Generator Loss: 2.2447
# Epoch 375/1000... Discriminator Loss: 0.9502... Generator Loss: 2.0278
# Epoch 376/1000... Discriminator Loss: 0.9342... Generator Loss: 2.1228
# Epoch 377/1000... Discriminator Loss: 0.9937... Generator Loss: 2.0997
# Epoch 378/1000... Discriminator Loss: 0.8703... Generator Loss: 2.1005
# Epoch 379/1000... Discriminator Loss: 0.9141... Generator Loss: 1.9347
# Epoch 380/1000... Discriminator Loss: 0.9315... Generator Loss: 2.1725
# Epoch 381/1000... Discriminator Loss: 0.9220... Generator Loss: 2.2040
# Epoch 382/1000... Discriminator Loss: 0.9369... Generator Loss: 2.1113
# Epoch 383/1000... Discriminator Loss: 0.8909... Generator Loss: 2.0749
# Epoch 384/1000... Discriminator Loss: 0.9126... Generator Loss: 1.9695
# Epoch 385/1000... Discriminator Loss: 0.9046... Generator Loss: 1.8711
# Epoch 386/1000... Discriminator Loss: 0.9955... Generator Loss: 1.8519
# Epoch 387/1000... Discriminator Loss: 0.8649... Generator Loss: 2.1026
# Epoch 388/1000... Discriminator Loss: 0.8710... Generator Loss: 2.3715
# Epoch 389/1000... Discriminator Loss: 0.9602... Generator Loss: 1.7737
# Epoch 390/1000... Discriminator Loss: 0.8868... Generator Loss: 2.3515
# Epoch 391/1000... Discriminator Loss: 0.8780... Generator Loss: 2.2461
# Epoch 392/1000... Discriminator Loss: 0.8794... Generator Loss: 2.1360
# Epoch 393/1000... Discriminator Loss: 0.9312... Generator Loss: 1.9122
# Epoch 394/1000... Discriminator Loss: 0.8824... Generator Loss: 2.3471
# Epoch 395/1000... Discriminator Loss: 0.8875... Generator Loss: 2.1469
# Epoch 396/1000... Discriminator Loss: 0.8482... Generator Loss: 2.4274
# Epoch 397/1000... Discriminator Loss: 0.8490... Generator Loss: 2.0549
# Epoch 398/1000... Discriminator Loss: 0.8954... Generator Loss: 1.9079
# Epoch 399/1000... Discriminator Loss: 0.8859... Generator Loss: 2.1919
# Epoch 400/1000... Discriminator Loss: 0.9450... Generator Loss: 2.0105
# Epoch 401/1000... Discriminator Loss: 0.9542... Generator Loss: 2.4107
# Epoch 402/1000... Discriminator Loss: 1.0070... Generator Loss: 1.8916
# Epoch 403/1000... Discriminator Loss: 0.9173... Generator Loss: 2.5945
# Epoch 404/1000... Discriminator Loss: 0.8489... Generator Loss: 2.4121
# Epoch 405/1000... Discriminator Loss: 0.9605... Generator Loss: 1.9726
# Epoch 406/1000... Discriminator Loss: 0.9217... Generator Loss: 2.0633
# Epoch 407/1000... Discriminator Loss: 0.9443... Generator Loss: 1.8967
# Epoch 408/1000... Discriminator Loss: 0.9340... Generator Loss: 2.0394
# Epoch 409/1000... Discriminator Loss: 0.9297... Generator Loss: 2.1083
# Epoch 410/1000... Discriminator Loss: 0.9861... Generator Loss: 2.4056
# Epoch 411/1000... Discriminator Loss: 0.9908... Generator Loss: 2.0950
# Epoch 412/1000... Discriminator Loss: 0.9502... Generator Loss: 2.0771
# Epoch 413/1000... Discriminator Loss: 1.0247... Generator Loss: 2.2667
# Epoch 414/1000... Discriminator Loss: 0.8502... Generator Loss: 2.0102
# Epoch 415/1000... Discriminator Loss: 0.9203... Generator Loss: 2.5872
# Epoch 416/1000... Discriminator Loss: 0.8441... Generator Loss: 2.2091
# Epoch 417/1000... Discriminator Loss: 0.9284... Generator Loss: 2.1151
# Epoch 418/1000... Discriminator Loss: 0.8742... Generator Loss: 1.9491
# Epoch 419/1000... Discriminator Loss: 0.9789... Generator Loss: 1.9347
# Epoch 420/1000... Discriminator Loss: 1.0054... Generator Loss: 1.9412
# Epoch 421/1000... Discriminator Loss: 0.8999... Generator Loss: 1.8126
# Epoch 422/1000... Discriminator Loss: 0.8807... Generator Loss: 2.1388
# Epoch 423/1000... Discriminator Loss: 0.8722... Generator Loss: 2.2638
# Epoch 424/1000... Discriminator Loss: 0.9614... Generator Loss: 2.1772
# Epoch 425/1000... Discriminator Loss: 1.0917... Generator Loss: 1.7504
# Epoch 426/1000... Discriminator Loss: 0.9601... Generator Loss: 2.2290
# Epoch 427/1000... Discriminator Loss: 0.9342... Generator Loss: 1.8244
# Epoch 428/1000... Discriminator Loss: 0.8990... Generator Loss: 2.6178
# Epoch 429/1000... Discriminator Loss: 0.9981... Generator Loss: 2.0079
# Epoch 430/1000... Discriminator Loss: 1.0417... Generator Loss: 1.8005
# Epoch 431/1000... Discriminator Loss: 0.9277... Generator Loss: 1.8167
# Epoch 432/1000... Discriminator Loss: 0.9915... Generator Loss: 2.1381
# Epoch 433/1000... Discriminator Loss: 0.9623... Generator Loss: 2.5992
# Epoch 434/1000... Discriminator Loss: 0.8553... Generator Loss: 2.2873
# Epoch 435/1000... Discriminator Loss: 0.9430... Generator Loss: 1.8097
# Epoch 436/1000... Discriminator Loss: 1.2231... Generator Loss: 1.4801
# Epoch 437/1000... Discriminator Loss: 0.9800... Generator Loss: 2.4953
# Epoch 438/1000... Discriminator Loss: 0.9997... Generator Loss: 1.6691
# Epoch 439/1000... Discriminator Loss: 0.9678... Generator Loss: 1.8263
# Epoch 440/1000... Discriminator Loss: 0.9462... Generator Loss: 2.3137
# Epoch 441/1000... Discriminator Loss: 1.0270... Generator Loss: 1.8942
# Epoch 442/1000... Discriminator Loss: 0.8665... Generator Loss: 2.6537
# Epoch 443/1000... Discriminator Loss: 0.9197... Generator Loss: 2.2942
# Epoch 444/1000... Discriminator Loss: 1.0971... Generator Loss: 1.6942
# Epoch 445/1000... Discriminator Loss: 1.0393... Generator Loss: 2.1279
# Epoch 446/1000... Discriminator Loss: 0.9913... Generator Loss: 2.0129
# Epoch 447/1000... Discriminator Loss: 1.0469... Generator Loss: 2.8718
# Epoch 448/1000... Discriminator Loss: 0.8360... Generator Loss: 2.5309
# Epoch 449/1000... Discriminator Loss: 1.0150... Generator Loss: 2.0215
# Epoch 450/1000... Discriminator Loss: 0.9871... Generator Loss: 2.0923
# Epoch 451/1000... Discriminator Loss: 0.8686... Generator Loss: 2.1134
# Epoch 452/1000... Discriminator Loss: 0.9849... Generator Loss: 1.8028
# Epoch 453/1000... Discriminator Loss: 1.0414... Generator Loss: 2.2921
# Epoch 454/1000... Discriminator Loss: 0.9004... Generator Loss: 2.2019
# Epoch 455/1000... Discriminator Loss: 0.9765... Generator Loss: 1.9651
# Epoch 456/1000... Discriminator Loss: 0.9415... Generator Loss: 2.2092
# Epoch 457/1000... Discriminator Loss: 1.0528... Generator Loss: 2.2152
# Epoch 458/1000... Discriminator Loss: 1.0606... Generator Loss: 1.6509
# Epoch 459/1000... Discriminator Loss: 0.9253... Generator Loss: 2.1907
# Epoch 460/1000... Discriminator Loss: 0.9110... Generator Loss: 2.2151
# Epoch 461/1000... Discriminator Loss: 1.0086... Generator Loss: 1.8042
# Epoch 462/1000... Discriminator Loss: 0.9075... Generator Loss: 1.9355
# Epoch 463/1000... Discriminator Loss: 1.0187... Generator Loss: 2.4213
# Epoch 464/1000... Discriminator Loss: 0.8896... Generator Loss: 2.3098
# Epoch 465/1000... Discriminator Loss: 0.9795... Generator Loss: 2.0201
# Epoch 466/1000... Discriminator Loss: 0.9659... Generator Loss: 1.8164
# Epoch 467/1000... Discriminator Loss: 1.0498... Generator Loss: 1.9239
# Epoch 468/1000... Discriminator Loss: 1.1416... Generator Loss: 1.6252
# Epoch 469/1000... Discriminator Loss: 0.9526... Generator Loss: 1.9262
# Epoch 470/1000... Discriminator Loss: 0.9825... Generator Loss: 2.0069
# Epoch 471/1000... Discriminator Loss: 0.8866... Generator Loss: 2.1149
# Epoch 472/1000... Discriminator Loss: 0.9281... Generator Loss: 2.2540
# Epoch 473/1000... Discriminator Loss: 1.0147... Generator Loss: 2.0289
# Epoch 474/1000... Discriminator Loss: 0.8983... Generator Loss: 2.2379
# Epoch 475/1000... Discriminator Loss: 1.1254... Generator Loss: 1.7304
# Epoch 476/1000... Discriminator Loss: 0.8797... Generator Loss: 2.1877
# Epoch 477/1000... Discriminator Loss: 0.8560... Generator Loss: 2.4212
# Epoch 478/1000... Discriminator Loss: 1.0979... Generator Loss: 1.5107
# Epoch 479/1000... Discriminator Loss: 0.9279... Generator Loss: 2.2317
# Epoch 480/1000... Discriminator Loss: 0.8538... Generator Loss: 2.2293
# Epoch 481/1000... Discriminator Loss: 0.9373... Generator Loss: 2.3059
# Epoch 482/1000... Discriminator Loss: 0.8159... Generator Loss: 2.3090
# Epoch 483/1000... Discriminator Loss: 0.9395... Generator Loss: 2.1180
# Epoch 484/1000... Discriminator Loss: 0.9708... Generator Loss: 2.0112
# Epoch 485/1000... Discriminator Loss: 0.9245... Generator Loss: 2.0004
# Epoch 486/1000... Discriminator Loss: 0.9878... Generator Loss: 2.0452
# Epoch 487/1000... Discriminator Loss: 0.9458... Generator Loss: 1.8776
# Epoch 488/1000... Discriminator Loss: 0.9081... Generator Loss: 2.0247
# Epoch 489/1000... Discriminator Loss: 0.8689... Generator Loss: 2.1196
# Epoch 490/1000... Discriminator Loss: 0.8902... Generator Loss: 2.2914
# Epoch 491/1000... Discriminator Loss: 0.9639... Generator Loss: 1.8717
# Epoch 492/1000... Discriminator Loss: 0.9571... Generator Loss: 1.8789
# Epoch 493/1000... Discriminator Loss: 0.8950... Generator Loss: 2.4860
# Epoch 494/1000... Discriminator Loss: 1.0958... Generator Loss: 1.6050
# Epoch 495/1000... Discriminator Loss: 0.8700... Generator Loss: 1.8506
# Epoch 496/1000... Discriminator Loss: 0.8506... Generator Loss: 2.1965
# Epoch 497/1000... Discriminator Loss: 0.7938... Generator Loss: 2.1223
# Epoch 498/1000... Discriminator Loss: 0.9307... Generator Loss: 1.8316
# Epoch 499/1000... Discriminator Loss: 0.9281... Generator Loss: 2.2756
# Epoch 500/1000... Discriminator Loss: 0.8852... Generator Loss: 2.1217
# Epoch 501/1000... Discriminator Loss: 0.8401... Generator Loss: 2.2245
# Epoch 502/1000... Discriminator Loss: 0.9019... Generator Loss: 2.0070
# Epoch 503/1000... Discriminator Loss: 1.0490... Generator Loss: 1.7461
# Epoch 504/1000... Discriminator Loss: 0.8724... Generator Loss: 2.0620
# Epoch 505/1000... Discriminator Loss: 0.8664... Generator Loss: 1.8790
# Epoch 506/1000... Discriminator Loss: 0.9116... Generator Loss: 1.9243
# Epoch 507/1000... Discriminator Loss: 1.0172... Generator Loss: 1.8887
# Epoch 508/1000... Discriminator Loss: 0.8153... Generator Loss: 2.3485
# Epoch 509/1000... Discriminator Loss: 1.0506... Generator Loss: 1.8686
# Epoch 510/1000... Discriminator Loss: 1.0147... Generator Loss: 1.8534
# Epoch 511/1000... Discriminator Loss: 0.9813... Generator Loss: 2.2712
# Epoch 512/1000... Discriminator Loss: 1.0610... Generator Loss: 1.9048
# Epoch 513/1000... Discriminator Loss: 0.8917... Generator Loss: 2.0699
# Epoch 514/1000... Discriminator Loss: 0.9166... Generator Loss: 1.9176
# Epoch 515/1000... Discriminator Loss: 1.0058... Generator Loss: 1.9355
# Epoch 516/1000... Discriminator Loss: 1.0590... Generator Loss: 1.8790
# Epoch 517/1000... Discriminator Loss: 0.9021... Generator Loss: 2.1242
# Epoch 518/1000... Discriminator Loss: 0.9401... Generator Loss: 2.4831
# Epoch 519/1000... Discriminator Loss: 0.9143... Generator Loss: 2.0559
# Epoch 520/1000... Discriminator Loss: 0.9910... Generator Loss: 1.9292
# Epoch 521/1000... Discriminator Loss: 0.9632... Generator Loss: 1.8706
# Epoch 522/1000... Discriminator Loss: 0.9806... Generator Loss: 2.3175
# Epoch 523/1000... Discriminator Loss: 1.1763... Generator Loss: 1.8231
# Epoch 524/1000... Discriminator Loss: 0.8913... Generator Loss: 1.9312
# Epoch 525/1000... Discriminator Loss: 1.0105... Generator Loss: 1.9691
# Epoch 526/1000... Discriminator Loss: 0.9775... Generator Loss: 2.2709
# Epoch 527/1000... Discriminator Loss: 0.8178... Generator Loss: 2.1231
# Epoch 528/1000... Discriminator Loss: 0.8810... Generator Loss: 1.9626
# Epoch 529/1000... Discriminator Loss: 0.9649... Generator Loss: 1.7765
# Epoch 530/1000... Discriminator Loss: 0.8858... Generator Loss: 2.2409
# Epoch 531/1000... Discriminator Loss: 1.2111... Generator Loss: 1.8318
# Epoch 532/1000... Discriminator Loss: 1.0286... Generator Loss: 2.0350
# Epoch 533/1000... Discriminator Loss: 0.9496... Generator Loss: 2.7512
# Epoch 534/1000... Discriminator Loss: 1.0201... Generator Loss: 2.0751
# Epoch 535/1000... Discriminator Loss: 0.9452... Generator Loss: 1.9482
# Epoch 536/1000... Discriminator Loss: 0.9380... Generator Loss: 2.0735
# Epoch 537/1000... Discriminator Loss: 0.8310... Generator Loss: 1.9906
# Epoch 538/1000... Discriminator Loss: 1.1021... Generator Loss: 2.0270
# Epoch 539/1000... Discriminator Loss: 0.9532... Generator Loss: 1.8554
# Epoch 540/1000... Discriminator Loss: 0.9324... Generator Loss: 1.9749
# Epoch 541/1000... Discriminator Loss: 1.0094... Generator Loss: 1.7830
# Epoch 542/1000... Discriminator Loss: 0.9721... Generator Loss: 1.8987
# Epoch 543/1000... Discriminator Loss: 0.8470... Generator Loss: 2.3420
# Epoch 544/1000... Discriminator Loss: 0.9210... Generator Loss: 1.8439
# Epoch 545/1000... Discriminator Loss: 0.8877... Generator Loss: 2.1394
# Epoch 546/1000... Discriminator Loss: 0.9763... Generator Loss: 2.0598
# Epoch 547/1000... Discriminator Loss: 0.8047... Generator Loss: 2.1288
# Epoch 548/1000... Discriminator Loss: 0.9757... Generator Loss: 1.9386
# Epoch 549/1000... Discriminator Loss: 1.0534... Generator Loss: 1.8580
# Epoch 550/1000... Discriminator Loss: 0.9634... Generator Loss: 1.9551
# Epoch 551/1000... Discriminator Loss: 0.9662... Generator Loss: 1.8266
# Epoch 552/1000... Discriminator Loss: 0.8815... Generator Loss: 1.9797
# Epoch 553/1000... Discriminator Loss: 1.0322... Generator Loss: 1.8785
# Epoch 554/1000... Discriminator Loss: 0.8179... Generator Loss: 2.3562
# Epoch 555/1000... Discriminator Loss: 0.8798... Generator Loss: 2.3014
# Epoch 556/1000... Discriminator Loss: 0.8782... Generator Loss: 2.2062
# Epoch 557/1000... Discriminator Loss: 0.8830... Generator Loss: 2.1757
# Epoch 558/1000... Discriminator Loss: 1.0785... Generator Loss: 2.0178
# Epoch 559/1000... Discriminator Loss: 0.8856... Generator Loss: 1.9796
# Epoch 560/1000... Discriminator Loss: 0.9443... Generator Loss: 1.9761
# Epoch 561/1000... Discriminator Loss: 0.9582... Generator Loss: 2.1861
# Epoch 562/1000... Discriminator Loss: 0.9060... Generator Loss: 2.2222
# Epoch 563/1000... Discriminator Loss: 1.0360... Generator Loss: 1.4965
# Epoch 564/1000... Discriminator Loss: 0.9133... Generator Loss: 2.2082
# Epoch 565/1000... Discriminator Loss: 0.9995... Generator Loss: 1.7735
# Epoch 566/1000... Discriminator Loss: 1.0014... Generator Loss: 1.9651
# Epoch 567/1000... Discriminator Loss: 0.8481... Generator Loss: 2.0081
# Epoch 568/1000... Discriminator Loss: 0.9326... Generator Loss: 1.9401
# Epoch 569/1000... Discriminator Loss: 0.8766... Generator Loss: 1.9986
# Epoch 570/1000... Discriminator Loss: 0.8578... Generator Loss: 2.1939
# Epoch 571/1000... Discriminator Loss: 0.9485... Generator Loss: 2.5358
# Epoch 572/1000... Discriminator Loss: 0.8462... Generator Loss: 2.0849
# Epoch 573/1000... Discriminator Loss: 0.9614... Generator Loss: 2.1004
# Epoch 574/1000... Discriminator Loss: 0.9518... Generator Loss: 1.9999
# Epoch 575/1000... Discriminator Loss: 0.9244... Generator Loss: 2.6359
# Epoch 576/1000... Discriminator Loss: 0.9350... Generator Loss: 2.1252
# Epoch 577/1000... Discriminator Loss: 0.9471... Generator Loss: 1.7797
# Epoch 578/1000... Discriminator Loss: 1.0057... Generator Loss: 1.7120
# Epoch 579/1000... Discriminator Loss: 0.8806... Generator Loss: 2.2704
# Epoch 580/1000... Discriminator Loss: 0.9382... Generator Loss: 1.8093
# Epoch 581/1000... Discriminator Loss: 0.9133... Generator Loss: 2.3431
# Epoch 582/1000... Discriminator Loss: 0.9903... Generator Loss: 2.2406
# Epoch 583/1000... Discriminator Loss: 1.0156... Generator Loss: 2.0450
# Epoch 584/1000... Discriminator Loss: 1.0334... Generator Loss: 1.8289
# Epoch 585/1000... Discriminator Loss: 0.9109... Generator Loss: 1.9811
# Epoch 586/1000... Discriminator Loss: 0.9680... Generator Loss: 2.0171
# Epoch 587/1000... Discriminator Loss: 0.9130... Generator Loss: 2.0516
# Epoch 588/1000... Discriminator Loss: 0.9543... Generator Loss: 2.1464
# Epoch 589/1000... Discriminator Loss: 0.8880... Generator Loss: 2.0972
# Epoch 590/1000... Discriminator Loss: 1.0100... Generator Loss: 2.0318
# Epoch 591/1000... Discriminator Loss: 1.0096... Generator Loss: 2.2314
# Epoch 592/1000... Discriminator Loss: 0.8816... Generator Loss: 2.2808
# Epoch 593/1000... Discriminator Loss: 1.0861... Generator Loss: 1.8741
# Epoch 594/1000... Discriminator Loss: 1.0438... Generator Loss: 1.8049
# Epoch 595/1000... Discriminator Loss: 0.9357... Generator Loss: 2.0679
# Epoch 596/1000... Discriminator Loss: 0.8102... Generator Loss: 2.2090
# Epoch 597/1000... Discriminator Loss: 1.0625... Generator Loss: 1.9362
# Epoch 598/1000... Discriminator Loss: 1.0075... Generator Loss: 1.9964
# Epoch 599/1000... Discriminator Loss: 0.8961... Generator Loss: 2.0007
# Epoch 600/1000... Discriminator Loss: 0.9922... Generator Loss: 2.1298
# Epoch 601/1000... Discriminator Loss: 1.0340... Generator Loss: 1.8275
# Epoch 602/1000... Discriminator Loss: 0.8789... Generator Loss: 2.0950
# Epoch 603/1000... Discriminator Loss: 0.9806... Generator Loss: 2.0020
# Epoch 604/1000... Discriminator Loss: 0.9573... Generator Loss: 2.0107
# Epoch 605/1000... Discriminator Loss: 0.9998... Generator Loss: 2.3674
# Epoch 606/1000... Discriminator Loss: 0.8396... Generator Loss: 2.1766
# Epoch 607/1000... Discriminator Loss: 1.0437... Generator Loss: 1.6391
# Epoch 608/1000... Discriminator Loss: 0.8861... Generator Loss: 1.8279
# Epoch 609/1000... Discriminator Loss: 0.8488... Generator Loss: 2.1071
# Epoch 610/1000... Discriminator Loss: 1.0095... Generator Loss: 1.7446
# Epoch 611/1000... Discriminator Loss: 0.9440... Generator Loss: 2.0165
# Epoch 612/1000... Discriminator Loss: 1.1559... Generator Loss: 1.7719
# Epoch 613/1000... Discriminator Loss: 1.2088... Generator Loss: 1.3991
# Epoch 614/1000... Discriminator Loss: 1.0333... Generator Loss: 2.0079
# Epoch 615/1000... Discriminator Loss: 0.9502... Generator Loss: 1.7271
# Epoch 616/1000... Discriminator Loss: 1.0078... Generator Loss: 1.9157
# Epoch 617/1000... Discriminator Loss: 0.8889... Generator Loss: 2.0642
# Epoch 618/1000... Discriminator Loss: 1.0257... Generator Loss: 2.0731
# Epoch 619/1000... Discriminator Loss: 0.8126... Generator Loss: 2.4181
# Epoch 620/1000... Discriminator Loss: 0.9628... Generator Loss: 2.2732
# Epoch 621/1000... Discriminator Loss: 0.9818... Generator Loss: 2.2259
# Epoch 622/1000... Discriminator Loss: 0.9282... Generator Loss: 2.0019
# Epoch 623/1000... Discriminator Loss: 1.0898... Generator Loss: 2.0992
# Epoch 624/1000... Discriminator Loss: 0.9236... Generator Loss: 2.3522
# Epoch 625/1000... Discriminator Loss: 0.8188... Generator Loss: 2.2736
# Epoch 626/1000... Discriminator Loss: 0.9877... Generator Loss: 1.6314
# Epoch 627/1000... Discriminator Loss: 0.9043... Generator Loss: 2.0830
# Epoch 628/1000... Discriminator Loss: 0.8337... Generator Loss: 2.1444
# Epoch 629/1000... Discriminator Loss: 0.8885... Generator Loss: 2.3948
# Epoch 630/1000... Discriminator Loss: 0.8564... Generator Loss: 2.0715
# Epoch 631/1000... Discriminator Loss: 0.9721... Generator Loss: 2.1355
# Epoch 632/1000... Discriminator Loss: 0.8843... Generator Loss: 1.9946
# Epoch 633/1000... Discriminator Loss: 0.9854... Generator Loss: 2.0826
# Epoch 634/1000... Discriminator Loss: 0.9906... Generator Loss: 1.6428
# Epoch 635/1000... Discriminator Loss: 0.9460... Generator Loss: 2.1068
# Epoch 636/1000... Discriminator Loss: 1.0595... Generator Loss: 2.0465
# Epoch 637/1000... Discriminator Loss: 1.0175... Generator Loss: 2.3894
# Epoch 638/1000... Discriminator Loss: 0.8920... Generator Loss: 2.3468
# Epoch 639/1000... Discriminator Loss: 1.0066... Generator Loss: 2.0383
# Epoch 640/1000... Discriminator Loss: 0.8602... Generator Loss: 2.4032
# Epoch 641/1000... Discriminator Loss: 1.0234... Generator Loss: 1.9406
# Epoch 642/1000... Discriminator Loss: 0.8929... Generator Loss: 2.4876
# Epoch 643/1000... Discriminator Loss: 0.8316... Generator Loss: 2.4216
# Epoch 644/1000... Discriminator Loss: 0.8643... Generator Loss: 2.0201
# Epoch 645/1000... Discriminator Loss: 0.9890... Generator Loss: 2.0097
# Epoch 646/1000... Discriminator Loss: 0.9717... Generator Loss: 1.7975
# Epoch 647/1000... Discriminator Loss: 0.8277... Generator Loss: 2.4237
# Epoch 648/1000... Discriminator Loss: 0.9349... Generator Loss: 2.2152
# Epoch 649/1000... Discriminator Loss: 1.0872... Generator Loss: 2.1715
# Epoch 650/1000... Discriminator Loss: 0.9385... Generator Loss: 1.9627
# Epoch 651/1000... Discriminator Loss: 0.9992... Generator Loss: 2.0032
# Epoch 652/1000... Discriminator Loss: 0.8090... Generator Loss: 2.1561
# Epoch 653/1000... Discriminator Loss: 0.9946... Generator Loss: 2.1705
# Epoch 654/1000... Discriminator Loss: 0.9614... Generator Loss: 1.9320
# Epoch 655/1000... Discriminator Loss: 0.9609... Generator Loss: 1.9184
# Epoch 656/1000... Discriminator Loss: 0.9222... Generator Loss: 2.1306
# Epoch 657/1000... Discriminator Loss: 0.8325... Generator Loss: 2.1983
# Epoch 658/1000... Discriminator Loss: 0.8243... Generator Loss: 2.4832
# Epoch 659/1000... Discriminator Loss: 0.9903... Generator Loss: 2.4161
# Epoch 660/1000... Discriminator Loss: 0.9165... Generator Loss: 2.0469
# Epoch 661/1000... Discriminator Loss: 0.9245... Generator Loss: 2.1449
# Epoch 662/1000... Discriminator Loss: 0.8728... Generator Loss: 2.2246
# Epoch 663/1000... Discriminator Loss: 0.8880... Generator Loss: 2.2592
# Epoch 664/1000... Discriminator Loss: 0.9853... Generator Loss: 1.8342
# Epoch 665/1000... Discriminator Loss: 0.9263... Generator Loss: 1.8973
# Epoch 666/1000... Discriminator Loss: 1.0455... Generator Loss: 1.7376
# Epoch 667/1000... Discriminator Loss: 0.9542... Generator Loss: 2.0260
# Epoch 668/1000... Discriminator Loss: 1.2621... Generator Loss: 1.6974
# Epoch 669/1000... Discriminator Loss: 0.7995... Generator Loss: 2.0341
# Epoch 670/1000... Discriminator Loss: 1.0101... Generator Loss: 1.8433
# Epoch 671/1000... Discriminator Loss: 1.0946... Generator Loss: 2.1671
# Epoch 672/1000... Discriminator Loss: 0.9454... Generator Loss: 2.1173
# Epoch 673/1000... Discriminator Loss: 1.0431... Generator Loss: 1.8537
# Epoch 674/1000... Discriminator Loss: 1.0735... Generator Loss: 1.8306
# Epoch 675/1000... Discriminator Loss: 0.9350... Generator Loss: 1.9633
# Epoch 676/1000... Discriminator Loss: 0.9580... Generator Loss: 2.2126
# Epoch 677/1000... Discriminator Loss: 0.8681... Generator Loss: 2.0907
# ...
# Epoch 776/1000... Discriminator Loss: 0.8509... Generator Loss: 2.0224
# Epoch 777/1000... Discriminator Loss: 0.8886... Generator Loss: 2.0204
# Epoch 778/1000... Discriminator Loss: 0.9065... Generator Loss: 2.2469
# Epoch 779/1000... Discriminator Loss: 0.9503... Generator Loss: 2.0260
# Epoch 780/1000... Discriminator Loss: 1.0147... Generator Loss: 1.9467
# Epoch 781/1000... Discriminator Loss: 0.9594... Generator Loss: 1.8327
# Epoch 782/1000... Discriminator Loss: 0.9220... Generator Loss: 2.0839
# Epoch 783/1000... Discriminator Loss: 0.9296... Generator Loss: 1.9140
# Epoch 784/1000... Discriminator Loss: 0.9347... Generator Loss: 2.2968
# Epoch 785/1000... Discriminator Loss: 1.0882... Generator Loss: 2.2027
# Epoch 786/1000... Discriminator Loss: 1.0230... Generator Loss: 1.8003
# Epoch 787/1000... Discriminator Loss: 0.8545... Generator Loss: 2.2295
# Epoch 788/1000... Discriminator Loss: 1.0880... Generator Loss: 1.7663
# Epoch 789/1000... Discriminator Loss: 1.0886... Generator Loss: 2.0589
# Epoch 790/1000... Discriminator Loss: 0.8537... Generator Loss: 2.2738
# Epoch 791/1000... Discriminator Loss: 0.9817... Generator Loss: 2.0821
# Epoch 792/1000... Discriminator Loss: 0.8935... Generator Loss: 1.9504
# Epoch 793/1000... Discriminator Loss: 0.9500... Generator Loss: 1.9173
# Epoch 794/1000... Discriminator Loss: 0.9949... Generator Loss: 1.8794
# Epoch 795/1000... Discriminator Loss: 1.0768... Generator Loss: 1.7648
# Epoch 796/1000... Discriminator Loss: 1.0677... Generator Loss: 1.8049
# Epoch 797/1000... Discriminator Loss: 0.8941... Generator Loss: 2.0513
# Epoch 798/1000... Discriminator Loss: 1.0191... Generator Loss: 1.6569
# Epoch 799/1000... Discriminator Loss: 0.8350... Generator Loss: 2.4545
# Epoch 800/1000... Discriminator Loss: 1.0457... Generator Loss: 1.9383
# Epoch 801/1000... Discriminator Loss: 0.9308... Generator Loss: 1.9857
# Epoch 802/1000... Discriminator Loss: 0.8825... Generator Loss: 2.2466
# Epoch 803/1000... Discriminator Loss: 0.9531... Generator Loss: 2.1092
# Epoch 804/1000... Discriminator Loss: 1.0105... Generator Loss: 1.7011
# Epoch 805/1000... Discriminator Loss: 1.0563... Generator Loss: 1.4534
# Epoch 806/1000... Discriminator Loss: 0.9755... Generator Loss: 2.2714
# Epoch 807/1000... Discriminator Loss: 0.9478... Generator Loss: 2.0696
# Epoch 808/1000... Discriminator Loss: 0.9696... Generator Loss: 2.0620
# Epoch 809/1000... Discriminator Loss: 0.8291... Generator Loss: 2.2255
# Epoch 810/1000... Discriminator Loss: 1.0146... Generator Loss: 1.7553
# Epoch 811/1000... Discriminator Loss: 0.9196... Generator Loss: 2.1266
# Epoch 812/1000... Discriminator Loss: 1.0032... Generator Loss: 2.1099
# Epoch 813/1000... Discriminator Loss: 1.0029... Generator Loss: 1.6050
# Epoch 814/1000... Discriminator Loss: 0.8853... Generator Loss: 1.8999
# Epoch 815/1000... Discriminator Loss: 0.8924... Generator Loss: 2.0258
# Epoch 816/1000... Discriminator Loss: 0.9800... Generator Loss: 1.7716
# Epoch 817/1000... Discriminator Loss: 1.0450... Generator Loss: 1.7256
# Epoch 818/1000... Discriminator Loss: 0.8446... Generator Loss: 2.0940
# Epoch 819/1000... Discriminator Loss: 0.9277... Generator Loss: 2.1924
# Epoch 820/1000... Discriminator Loss: 0.9648... Generator Loss: 2.0925
# Epoch 821/1000... Discriminator Loss: 0.9839... Generator Loss: 1.8333
# Epoch 822/1000... Discriminator Loss: 0.9007... Generator Loss: 2.2333
# Epoch 823/1000... Discriminator Loss: 0.9095... Generator Loss: 2.1222
# Epoch 824/1000... Discriminator Loss: 1.0532... Generator Loss: 1.8627
# Epoch 825/1000... Discriminator Loss: 0.9183... Generator Loss: 1.7705
# Epoch 826/1000... Discriminator Loss: 0.8893... Generator Loss: 2.0267
# Epoch 827/1000... Discriminator Loss: 0.8882... Generator Loss: 1.9960
# Epoch 828/1000... Discriminator Loss: 0.9303... Generator Loss: 2.3049
# Epoch 829/1000... Discriminator Loss: 0.8979... Generator Loss: 2.1079
# Epoch 830/1000... Discriminator Loss: 0.9340... Generator Loss: 1.9775
# Epoch 831/1000... Discriminator Loss: 0.9130... Generator Loss: 2.3851
# Epoch 832/1000... Discriminator Loss: 0.8700... Generator Loss: 2.4024
# Epoch 833/1000... Discriminator Loss: 1.0203... Generator Loss: 2.1412
# Epoch 834/1000... Discriminator Loss: 0.9973... Generator Loss: 1.9122
# Epoch 835/1000... Discriminator Loss: 1.0291... Generator Loss: 2.3474
# Epoch 836/1000... Discriminator Loss: 0.8964... Generator Loss: 2.3845
# Epoch 837/1000... Discriminator Loss: 0.8754... Generator Loss: 2.0662
# Epoch 838/1000... Discriminator Loss: 0.8900... Generator Loss: 1.9709
# Epoch 839/1000... Discriminator Loss: 0.9806... Generator Loss: 2.0200
# Epoch 840/1000... Discriminator Loss: 1.0260... Generator Loss: 1.8375
# Epoch 841/1000... Discriminator Loss: 0.9695... Generator Loss: 1.8053
# Epoch 842/1000... Discriminator Loss: 0.9044... Generator Loss: 1.9433
# Epoch 843/1000... Discriminator Loss: 0.9172... Generator Loss: 2.1490
# Epoch 844/1000... Discriminator Loss: 0.9666... Generator Loss: 1.7011
# Epoch 845/1000... Discriminator Loss: 0.9484... Generator Loss: 1.7794
# Epoch 846/1000... Discriminator Loss: 1.0901... Generator Loss: 1.7395
# Epoch 847/1000... Discriminator Loss: 0.9002... Generator Loss: 1.9517
# Epoch 848/1000... Discriminator Loss: 0.9944... Generator Loss: 2.1386
# Epoch 849/1000... Discriminator Loss: 0.8739... Generator Loss: 2.6307
# Epoch 850/1000... Discriminator Loss: 0.9521... Generator Loss: 1.9370
# Epoch 851/1000... Discriminator Loss: 0.9079... Generator Loss: 1.9920
# Epoch 852/1000... Discriminator Loss: 0.8867... Generator Loss: 2.1181
# Epoch 853/1000... Discriminator Loss: 0.9429... Generator Loss: 2.0301
# Epoch 854/1000... Discriminator Loss: 0.9317... Generator Loss: 2.0827
# Epoch 855/1000... Discriminator Loss: 0.8634... Generator Loss: 2.1736
# Epoch 856/1000... Discriminator Loss: 1.0457... Generator Loss: 1.7215
# Epoch 857/1000... Discriminator Loss: 0.8763... Generator Loss: 2.2167
# Epoch 858/1000... Discriminator Loss: 1.0419... Generator Loss: 1.9702
# Epoch 859/1000... Discriminator Loss: 0.9467... Generator Loss: 2.0137
# Epoch 860/1000... Discriminator Loss: 0.8744... Generator Loss: 2.5317
# Epoch 861/1000... Discriminator Loss: 0.8700... Generator Loss: 2.2514
# Epoch 862/1000... Discriminator Loss: 0.8748... Generator Loss: 2.2427
# Epoch 863/1000... Discriminator Loss: 0.9996... Generator Loss: 1.9971
# Epoch 864/1000... Discriminator Loss: 0.8712... Generator Loss: 2.2985
# Epoch 865/1000... Discriminator Loss: 0.9120... Generator Loss: 1.8500
# Epoch 866/1000... Discriminator Loss: 0.9069... Generator Loss: 2.1774
# Epoch 867/1000... Discriminator Loss: 1.1561... Generator Loss: 1.6956
# Epoch 868/1000... Discriminator Loss: 0.9700... Generator Loss: 1.6860
# Epoch 869/1000... Discriminator Loss: 1.0086... Generator Loss: 1.5775
# Epoch 870/1000... Discriminator Loss: 0.8487... Generator Loss: 2.0723
# Epoch 871/1000... Discriminator Loss: 0.9252... Generator Loss: 1.8930
# Epoch 872/1000... Discriminator Loss: 1.0037... Generator Loss: 1.7762
# Epoch 873/1000... Discriminator Loss: 0.9248... Generator Loss: 2.1488
# Epoch 874/1000... Discriminator Loss: 0.8663... Generator Loss: 2.1505
# Epoch 875/1000... Discriminator Loss: 0.9982... Generator Loss: 1.8370
# Epoch 876/1000... Discriminator Loss: 0.9499... Generator Loss: 2.0638
# Epoch 877/1000... Discriminator Loss: 0.9586... Generator Loss: 2.0615
# Epoch 878/1000... Discriminator Loss: 0.8810... Generator Loss: 1.9340
# Epoch 879/1000... Discriminator Loss: 0.9387... Generator Loss: 1.9466
# Epoch 880/1000... Discriminator Loss: 0.8252... Generator Loss: 2.1276
# Epoch 881/1000... Discriminator Loss: 0.8666... Generator Loss: 2.0989
# Epoch 882/1000... Discriminator Loss: 0.8699... Generator Loss: 2.0866
# Epoch 883/1000... Discriminator Loss: 0.9704... Generator Loss: 1.9682
# Epoch 884/1000... Discriminator Loss: 0.9108... Generator Loss: 2.0569
# Epoch 885/1000... Discriminator Loss: 0.9283... Generator Loss: 2.0245
# Epoch 886/1000... Discriminator Loss: 0.8516... Generator Loss: 2.1687
# Epoch 887/1000... Discriminator Loss: 1.0620... Generator Loss: 2.0450
# Epoch 888/1000... Discriminator Loss: 0.9009... Generator Loss: 2.0304
# Epoch 889/1000... Discriminator Loss: 0.9138... Generator Loss: 1.8909
# Epoch 890/1000... Discriminator Loss: 0.9286... Generator Loss: 2.2525
# Epoch 891/1000... Discriminator Loss: 0.9826... Generator Loss: 1.9952
# Epoch 892/1000... Discriminator Loss: 0.9190... Generator Loss: 2.2393
# Epoch 893/1000... Discriminator Loss: 1.0012... Generator Loss: 1.7062
# Epoch 894/1000... Discriminator Loss: 0.9429... Generator Loss: 2.0770
# Epoch 895/1000... Discriminator Loss: 0.9204... Generator Loss: 1.8733
# Epoch 896/1000... Discriminator Loss: 0.8726... Generator Loss: 2.0612
# Epoch 897/1000... Discriminator Loss: 1.0079... Generator Loss: 2.1708
# Epoch 898/1000... Discriminator Loss: 0.9823... Generator Loss: 1.7932
# Epoch 899/1000... Discriminator Loss: 0.8819... Generator Loss: 2.1117
# Epoch 900/1000... Discriminator Loss: 0.8602... Generator Loss: 2.2360
# Epoch 901/1000... Discriminator Loss: 0.9697... Generator Loss: 1.7290
# Epoch 902/1000... Discriminator Loss: 0.8631... Generator Loss: 2.4382
# Epoch 903/1000... Discriminator Loss: 0.9843... Generator Loss: 1.9595
# Epoch 904/1000... Discriminator Loss: 0.9565... Generator Loss: 1.9399
# Epoch 905/1000... Discriminator Loss: 0.8928... Generator Loss: 2.1410
# Epoch 906/1000... Discriminator Loss: 1.0264... Generator Loss: 1.7429
# Epoch 907/1000... Discriminator Loss: 0.8961... Generator Loss: 2.0404
# Epoch 908/1000... Discriminator Loss: 0.9362... Generator Loss: 2.0526
# Epoch 909/1000... Discriminator Loss: 0.9234... Generator Loss: 1.8774
# Epoch 910/1000... Discriminator Loss: 0.9219... Generator Loss: 1.8323
# Epoch 911/1000... Discriminator Loss: 0.8337... Generator Loss: 2.5492
# Epoch 912/1000... Discriminator Loss: 1.1018... Generator Loss: 2.0981
# Epoch 913/1000... Discriminator Loss: 0.8514... Generator Loss: 2.3358
# Epoch 914/1000... Discriminator Loss: 0.9058... Generator Loss: 2.1215
# Epoch 915/1000... Discriminator Loss: 0.8750... Generator Loss: 2.5352
# Epoch 916/1000... Discriminator Loss: 0.9388... Generator Loss: 2.0805
# Epoch 917/1000... Discriminator Loss: 0.9227... Generator Loss: 2.0021
# Epoch 918/1000... Discriminator Loss: 0.9901... Generator Loss: 1.6584
# Epoch 919/1000... Discriminator Loss: 0.8771... Generator Loss: 2.3079
# Epoch 920/1000... Discriminator Loss: 0.9983... Generator Loss: 1.9991
# Epoch 921/1000... Discriminator Loss: 0.8512... Generator Loss: 2.1885
# Epoch 922/1000... Discriminator Loss: 0.8994... Generator Loss: 2.0516
# Epoch 923/1000... Discriminator Loss: 0.8684... Generator Loss: 2.4456
# Epoch 924/1000... Discriminator Loss: 1.0233... Generator Loss: 1.7633
# Epoch 925/1000... Discriminator Loss: 0.8134... Generator Loss: 2.1290
# Epoch 926/1000... Discriminator Loss: 0.9305... Generator Loss: 2.0331
# Epoch 927/1000... Discriminator Loss: 0.9222... Generator Loss: 2.0046
# Epoch 928/1000... Discriminator Loss: 0.9984... Generator Loss: 1.9048
# Epoch 929/1000... Discriminator Loss: 0.9091... Generator Loss: 2.0902
# Epoch 930/1000... Discriminator Loss: 0.8427... Generator Loss: 2.1407
# Epoch 931/1000... Discriminator Loss: 1.0025... Generator Loss: 1.9965
# Epoch 932/1000... Discriminator Loss: 0.9535... Generator Loss: 1.9504
# Epoch 933/1000... Discriminator Loss: 0.9961... Generator Loss: 1.9678
# Epoch 934/1000... Discriminator Loss: 0.9171... Generator Loss: 1.9954
# Epoch 935/1000... Discriminator Loss: 0.8492... Generator Loss: 2.4944
# Epoch 936/1000... Discriminator Loss: 0.8667... Generator Loss: 2.1723
# Epoch 937/1000... Discriminator Loss: 0.9056... Generator Loss: 1.9326
# Epoch 938/1000... Discriminator Loss: 0.8986... Generator Loss: 2.1036
# Epoch 939/1000... Discriminator Loss: 0.8319... Generator Loss: 2.2745
# Epoch 940/1000... Discriminator Loss: 0.8827... Generator Loss: 2.3967
# Epoch 941/1000... Discriminator Loss: 0.9480... Generator Loss: 2.3077
# Epoch 942/1000... Discriminator Loss: 1.0278... Generator Loss: 2.0646
# Epoch 943/1000... Discriminator Loss: 0.8901... Generator Loss: 2.1505
# Epoch 944/1000... Discriminator Loss: 0.9009... Generator Loss: 1.8042
# Epoch 945/1000... Discriminator Loss: 0.9251... Generator Loss: 2.3469
# Epoch 946/1000... Discriminator Loss: 0.8763... Generator Loss: 2.1428
# Epoch 947/1000... Discriminator Loss: 0.9698... Generator Loss: 1.8401
# Epoch 948/1000... Discriminator Loss: 1.0525... Generator Loss: 2.0759
# Epoch 949/1000... Discriminator Loss: 0.9035... Generator Loss: 2.1912
# Epoch 950/1000... Discriminator Loss: 1.0456... Generator Loss: 1.9710
# Epoch 951/1000... Discriminator Loss: 0.8272... Generator Loss: 2.1337
# Epoch 952/1000... Discriminator Loss: 0.9680... Generator Loss: 1.9978
# Epoch 953/1000... Discriminator Loss: 0.9272... Generator Loss: 2.0728
# Epoch 954/1000... Discriminator Loss: 0.9421... Generator Loss: 1.7502
# Epoch 955/1000... Discriminator Loss: 0.8919... Generator Loss: 2.2187
# Epoch 956/1000... Discriminator Loss: 0.9650... Generator Loss: 2.1317
# Epoch 957/1000... Discriminator Loss: 0.9270... Generator Loss: 2.0393
# Epoch 958/1000... Discriminator Loss: 0.9418... Generator Loss: 2.0183
# Epoch 959/1000... Discriminator Loss: 0.9406... Generator Loss: 2.1280
# Epoch 960/1000... Discriminator Loss: 0.8139... Generator Loss: 2.2728
# Epoch 961/1000... Discriminator Loss: 0.8615... Generator Loss: 2.0333
# Epoch 962/1000... Discriminator Loss: 0.9370... Generator Loss: 1.8919
# Epoch 963/1000... Discriminator Loss: 0.8942... Generator Loss: 2.1151
# Epoch 964/1000... Discriminator Loss: 0.9029... Generator Loss: 1.9921
# Epoch 965/1000... Discriminator Loss: 0.7894... Generator Loss: 2.3761
# Epoch 966/1000... Discriminator Loss: 0.8683... Generator Loss: 2.5844
# Epoch 967/1000... Discriminator Loss: 0.8322... Generator Loss: 2.2747
# Epoch 968/1000... Discriminator Loss: 0.8956... Generator Loss: 2.3090
# Epoch 969/1000... Discriminator Loss: 0.8109... Generator Loss: 2.3144
# Epoch 970/1000... Discriminator Loss: 0.8858... Generator Loss: 2.3025
# Epoch 971/1000... Discriminator Loss: 0.9065... Generator Loss: 2.2362
# Epoch 972/1000... Discriminator Loss: 0.9385... Generator Loss: 1.8919
# Epoch 973/1000... Discriminator Loss: 0.9421... Generator Loss: 1.8443
# Epoch 974/1000... Discriminator Loss: 0.9582... Generator Loss: 1.9831
# Epoch 975/1000... Discriminator Loss: 0.8339... Generator Loss: 1.9903
# Epoch 976/1000... Discriminator Loss: 0.9512... Generator Loss: 2.3011
# Epoch 977/1000... Discriminator Loss: 0.9219... Generator Loss: 2.1771
# Epoch 978/1000... Discriminator Loss: 0.8911... Generator Loss: 1.8443
# Epoch 979/1000... Discriminator Loss: 0.9528... Generator Loss: 2.0261
# Epoch 980/1000... Discriminator Loss: 0.9261... Generator Loss: 2.0542
# Epoch 981/1000... Discriminator Loss: 0.9441... Generator Loss: 2.1252
# Epoch 982/1000... Discriminator Loss: 0.8868... Generator Loss: 2.0284
# Epoch 983/1000... Discriminator Loss: 0.9792... Generator Loss: 2.0087
# Epoch 984/1000... Discriminator Loss: 0.9220... Generator Loss: 1.9254
# Epoch 985/1000... Discriminator Loss: 0.9021... Generator Loss: 2.1903
# Epoch 986/1000... Discriminator Loss: 1.0806... Generator Loss: 1.7351
# Epoch 987/1000... Discriminator Loss: 0.9383... Generator Loss: 2.0774
# Epoch 988/1000... Discriminator Loss: 0.9378... Generator Loss: 2.1379
# Epoch 989/1000... Discriminator Loss: 0.8731... Generator Loss: 2.1549
# Epoch 990/1000... Discriminator Loss: 0.8833... Generator Loss: 2.0265
# Epoch 991/1000... Discriminator Loss: 0.8232... Generator Loss: 2.1127
# Epoch 992/1000... Discriminator Loss: 0.8945... Generator Loss: 1.9488
# Epoch 993/1000... Discriminator Loss: 0.8772... Generator Loss: 2.0920
# Epoch 994/1000... Discriminator Loss: 0.8745... Generator Loss: 2.1469
# Epoch 995/1000... Discriminator Loss: 0.9347... Generator Loss: 1.9309
# Epoch 996/1000... Discriminator Loss: 0.8348... Generator Loss: 2.1426
# Epoch 997/1000... Discriminator Loss: 0.9617... Generator Loss: 2.2492
# Epoch 998/1000... Discriminator Loss: 1.0039... Generator Loss: 1.6973
# Epoch 999/1000... Discriminator Loss: 1.0145... Generator Loss: 1.7503
# Epoch 1000/1000... Discriminator Loss: 0.8560... Generator Loss: 2.2070

# %% [markdown]
# ## Training loss
#
# Here we'll check out the training losses for the generator and discriminator.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator')
plt.plot(losses.T[1], label='Generator')
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# Here we can view samples of images from the generator. First we'll look at images taken while training.

# %%
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(7,7), nrows=4, ncols=4, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')
    
    return fig, axes

# %%
# Load samples from generator taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %% [markdown]
# These are samples from the final training epoch. You can see the generator is able to reproduce numbers like 5, 7, 3, 0, 9. Since this is just a sample, it isn't representative of the full range of images this generator can make.

# %%
_ = view_samples(-1, samples)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-76e3821ac0ef> in <module>()
# ----> 1 _ = view_samples(-1, samples)
#
# <ipython-input-37-1210b6e4882d> in view_samples(epoch, samples)
#       4         ax.xaxis.set_visible(False)
#       5         ax.yaxis.set_visible(False)
# ----> 6         im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')
#       7
#       8     return fig, axes
#
# ValueError: cannot reshape array of size 12544 into shape (28,28)

# %% [markdown]
# Below I'm showing the generated images as the network was training, every 10 epochs. With bonus optical illusion!

# %%
rows, cols = 10, 6
fig, axes = plt.subplots(figsize=(7,12), nrows=rows, ncols=cols, sharex=True, sharey=True)

for sample, ax_row in zip(samples[::int(len(samples)/rows)], axes):
    for img, ax in zip(sample[::int(len(sample)/cols)], ax_row):
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

# %% [markdown]
# It starts out as all noise. Then it learns to make only the center white and the rest black. You can start to see some number like structures appear out of the noise. Looks like 1, 9, and 8 show up first. Then, it learns 5 and 3.

# %% [markdown]
# ## Sampling from the generator
#
# We can also get completely new images from the generator by using the checkpoint we saved after training. We just need to pass in a new latent vector $z$ and we'll get new samples!

# %%
saver = tf.train.Saver(var_list=g_vars)
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    sample_z = np.random.uniform(-1, 1, size=(16, z_size))
    gen_samples = sess.run(
                   generator(input_z, input_size, n_units=g_hidden_size, reuse=True, alpha=alpha),
                   feed_dict={input_z: sample_z})
view_samples(0, [gen_samples])
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/generator.ckpt
# (<Figure size 504x504 with 16 Axes>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd2e1b9fd68>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7fd2e1b52080>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7fd2e1b690b8>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7fd2e1bc50f0>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd2e1bea2b0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7fd2e1cce668>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7fd2e1cfaa58>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7fd2e1c23e48>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd2e1b18278>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7fd2e1ac1668>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7fd2e1aeaa58>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7fd2e1a94e48>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x7fd2e1a46278>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7fd2e1a71668>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7fd2e1a18a58>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x7fd2e19c2e48>]],
#        dtype=object))
